# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

def plot_scenarios(csv_files, case_study, obj_mode, scenario_names):
    """
    Plot data from multiple CSV files into line charts with shared Y-axis ranges for columns.
    Add lines for max_hv, max_st, min_em, and min_ha on appropriate plots.
    
    Parameters:
        csv_files (list of str): List of CSV file paths to read.
        case_study (str): Case study name for output file naming.
        obj_mode (str): Objective mode for output file naming.
        scenario_names (list of str): List of scenario names corresponding to the CSV files.
    """
    # Initialize figure and axes for subplots
    fig, axes = plt.subplots(3, 1, figsize=(12, 12))
    
    # Read data and collect min/max values for shared y-axis
    all_oha, all_ohv, all_ogs = [], [], []
    dfs = [pd.read_csv(file) for file in csv_files]
    
    # Check columns and print head for debugging
    for df in dfs:
        # print(df.columns)
        # print(df.head())
        all_oha.extend(df['oha'].values)  # Ensure we're accessing columns correctly
        all_ohv.extend(df['ohv'].values)
        all_ogs.extend(df['ogs'].values)
    
    # Determine common y-axis ranges
    common_ylim_oha = (0, max(all_oha) * 1.1)
    common_ylim_ohv = (0, max(all_ohv) * 1.1)
    common_ylim_ogs = (0, max(all_ogs) * 1.1)
    
    # Plot Harvested Area (ha)
    for i, (df, scenario_name) in enumerate(zip(dfs, scenario_names)):
        axes[0].plot(df['period'].values, df['oha'].values, label=f"{scenario_name}")
        axes[0].set_ylim(common_ylim_oha)
    
    # Lines for max_hv, max_st, min_em, and min_ha
    axes[0].axhline(y=max(all_oha), color='r', linestyle='--', label='max_ha')
    axes[0].axhline(y=min(all_oha), color='g', linestyle='--', label='min_ha')
    
    axes[0].set_title(f"Harvested Area (ha)")
    axes[0].set_xlabel("Period")
    axes[0].set_ylabel("Harvested Area (ha)")
    
    # Plot Harvested Volume (m3)
    for i, (df, scenario_name) in enumerate(zip(dfs, scenario_names)):
        axes[1].plot(df['period'].values, df['ohv'].values, label=f"{scenario_name}")
        axes[1].set_ylim(common_ylim_ohv)
    
    # Lines for max_hv, max_st, min_em, and min_ha
    axes[1].axhline(y=max(all_ohv), color='r', linestyle='--', label='max_hv')
    axes[1].axhline(y=min(all_ohv), color='g', linestyle='--', label='min_em')  # Assuming min_em corresponds to min_ohv
    
    axes[1].set_title(f"Harvested Volume (m3)")
    axes[1].set_xlabel("Period")
    axes[1].set_ylabel("Harvested Volume (m3)")
    
    # Plot Growing Stock (m3)
    for i, (df, scenario_name) in enumerate(zip(dfs, scenario_names)):
        axes[2].plot(df['period'].values, df['ogs'].values, label=f"{scenario_name}")
        axes[2].set_ylim(common_ylim_ogs)
    
    # Lines for max_hv, max_st, min_em, and min_ha
    axes[2].axhline(y=max(all_ogs), color='r', linestyle='--', label='max_st')
    axes[2].axhline(y=min(all_ogs), color='g', linestyle='--', label='min_em')  # Assuming min_em corresponds to min_ogs
    
    axes[2].set_title(f"Growing Stock (m3)")
    axes[2].set_xlabel("Period")
    axes[2].set_ylabel("Growing Stock (m3)")

    # Add legend
    for ax in axes:
        ax.legend(loc="best")
    
    # Adjust layout
    plt.tight_layout()
    
    # Save the figure
    folder_path = os.path.join('./fig', case_study)
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    file_name = f"{case_study}_{obj_mode}_combined_scheduling_line.svg"
    file_path = os.path.join(folder_path, file_name)
    
    # Save as SVG (vector format)
    plt.savefig(file_path, format='svg')
    plt.show()
    plt.close()
    print(f"Plot saved to {file_path}")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming you have dataframes grouped by case study, obj_mode, and scenario
def plot_case_studies(case_studies, obj_modes, scenarios, metrics):
    """
    Hierarchical plots for case studies, objective modes, and scenarios.
    """
    fig, axes = plt.subplots(
        len(case_studies), len(obj_modes), figsize=(20, 10), sharey='row'
    )
    
    for i, metric in enumerate(metrics):
        for j, obj_mode in enumerate(obj_modes):
            ax = axes[i, j]
            
            # Plot metrics for each scenario
            for scenario in scenarios:
                # Replace with actual data filtering logic
                data = get_scenario_data(case_study, obj_mode, scenario)  # Function to fetch scenario data
                
                ax.plot(data['period'], data['oha'], label=f"Scenario {scenario} - Harvested Area", alpha=0.6)
                ax.plot(data['period'], data['ohv'], label=f"Scenario {scenario} - Harvested Volume", alpha=0.6)
                ax.plot(data['period'], data['ogs'], label=f"Scenario {scenario} - Growing Stock", alpha=0.6)
            
            ax.set_title(f"{case_study} - {obj_mode}")
            ax.set_xlabel("Period")
            if j == 0:
                ax.set_ylabel("Metric Value")
            if i == 0:
                ax.legend(loc="upper center", bbox_to_anchor=(0.5, 1.1), ncol=3)
    
    plt.tight_layout()
    plt.show()

# Example usage
case_studies = ["Case Study 1", "Case Study 2", "Case Study 3"]
obj_modes = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
scenarios = range(1, 12)  # 11 scenarios
metrics = ["oha", "ohv", "ogs"]
plot_case_studies(case_studies, obj_modes, scenarios, metrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 42
#      40 scenarios = range(1, 12)  # 11 scenarios
#      41 metrics = ["oha", "ohv", "ogs"]
# ---> 42 plot_case_studies(case_studies, obj_modes, scenarios, metrics)
#
# Cell In[14], line 21, in plot_case_studies(case_studies, obj_modes, scenarios, metrics)
#      18 # Plot metrics for each scenario
#      19 for scenario in scenarios:
#      20     # Replace with actual data filtering logic
# ---> 21     data = get_scenario_data(case_study, obj_mode, scenario)  # Function to fetch scenario data
#      23     ax.plot(data['period'], data['oha'], label=f"Scenario {scenario} - Harvested Area", alpha=0.6)
#      24     ax.plot(data['period'], data['ohv'], label=f"Scenario {scenario} - Harvested Volume", alpha=0.6)
#
# NameError: name 'get_scenario_data' is not defined

# %%
# Example usage
csv_files = ["equitysilver_max_hv_no_cons_compile_scenario.csv", "equitysilver_max_st_no_cons_compile_scenario_maxstock.csv", "equitysilver_min_em_no_cons_compile_scenario_minemission.csv", 
             "equitysilver_min_ha_no_cons_compile_scenario.csv"]
scenario_names = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "equitysilver", "ObjectiveModeY", scenario_names)

# %%
csv_files = ["equitysilver_max_hv_no_cons_compile_scenario.csv", "equitysilver_max_st_no_cons_compile_scenario_maxstock.csv", "equitysilver_min_em_no_cons_compile_scenario_minemission.csv", 
             "equitysilver_min_ha_no_cons_compile_scenario.csv"]
obj_mode = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "equitysilver", obj_mode, scenario_names='No_cons')
# Out:
# Plot saved to ./fig/equitysilver/equitysilver_No_cons_combined_scheduling_linechart.svg

# %%
csv_files = ["goldenbear_max_hv_no_cons_compile_scenario.csv", "goldenbear_max_st_no_cons_compile_scenario_maxstock.csv", "goldenbear_min_em_no_cons_compile_scenario_minemission.csv", 
             "goldenbear_min_ha_no_cons_compile_scenario.csv"]
obj_mode = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "goldenbear", obj_mode, scenario_names='No_cons')

# %%
csv_files = ["redchris_max_hv_no_cons_compile_scenario.csv", "redchris_max_st_no_cons_compile_scenario_maxstock.csv", "redchris_min_em_no_cons_compile_scenario_minemission.csv", 
             "redchris_min_ha_no_cons_compile_scenario.csv"]
obj_mode = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "redchris", obj_mode, scenario_names='No_cons')

# %%
csv_files = ["equitysilver_max_hv_bau_eqtslvr_compile_scenario.csv", "equitysilver_max_st_bau_eqtslvr_compile_scenario_maxstock.csv", "equitysilver_min_em_bau_eqtslvr_compile_scenario_minemission.csv", 
             "equitysilver_min_ha_bau_eqtslvr_compile_scenario.csv"]
obj_mode = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "equitysilver", obj_mode, scenario_names='bau_eqtslvr')

# %%
csv_files = ["goldenbear_max_hv_bau_gldbr_compile_scenario.csv", "goldenbear_max_st_bau_gldbr_compile_scenario_maxstock.csv", "goldenbear_min_em_bau_gldbr_compile_scenario_minemission.csv", 
             "goldenbear_min_ha_bau_gldbr_compile_scenario.csv"]
obj_mode = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "goldenbear", obj_mode, scenario_names='bau_gldbr')

# %%
csv_files = ["redchris_max_hv_bau_redchrs_compile_scenario.csv", "redchris_max_st_bau_redchrs_compile_scenario_maxstock.csv", "redchris_min_em_bau_redchrs_compile_scenario_minemission.csv", 
             "redchris_min_ha_bau_redchrs_compile_scenario.csv"]
obj_mode = ["Max_hv", "Max_st", "Min_em", "Min_ha"]
plot_scenarios(csv_files, "redchris", obj_mode, scenario_names='bau_redchrs')
