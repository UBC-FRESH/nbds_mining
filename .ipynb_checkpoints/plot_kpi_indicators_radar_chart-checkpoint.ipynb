# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import ws3.opt
import pickle
import numpy as np
from math import pi
import ipywidgets as widgets
from ipywidgets import interact
from util import generate_radar_chart, generate_subplots_radar_chart, create_grouped_bar_chart

# %%
equitysilver_max_hv= {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    # "Harvest Volume": [9.5385144e+07, 1.3344616e+08, 8.584663087e+07, 7.6308117e+07, 6.676960411e+07, 5.723109073e+07, 4.7692577e+07, 3.8154064e+07, 2.8615551e+07, 1.9077037e+07, 9.5385238e+06],
    "Net Emission": [-10187414, 2860992, -20190655, -37717399, -53571451, -69020879, -83747319, -96901488, -116527826, -127261518, -141630206],
    "Social Indicator": [100842, 141080, 90757, 80673, 70589, 60505, 50421, 40336, 30252, 20168, 10084],
    "Economic Indicator": [3438933, 4811151, 3095039, 2751146, 2407253, 2063360, 1719466, 1375573, 1031680, 687786, 343893],
    "Species Indicator": [0.7329, 0.7509, 0.7607, 0.7514, 0.7445, 0.7401, 0.7375, 0.7275, 0.7328, 0.7365, 0.7399],
    "Old Growth Indicator": [196384, 166327, 222922.6, 247449, 286878.4, 324882.5, 367419, 420221.3, 462754.7, 502643, 535463.1]
}

equitysilver_min_ha = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    # "Harvest Area": [3.8189149e+05, None, 3.3325811e+05, 2.8743943e+05, 2.4404208e+05, 2.0333523e+05, 1.6452611e+05, 1.2681471e+05, 9.060671199e+04, 5.7354080e+04, 2.7180641e+04],
    "Net Emissions": [-27541849, -155624647, -42297895, -55475110, -69237782, -83282990, -96462861, -109037924, -121829519, -133928525, -144780424],
    "Social Indicator": [92157, None, 82941, 73725, 64510, 55294, 46078, 36862, 27647, 18431, 9215],
    "Economic Indicator": [3142756, None, 2828481, 2514205, 2199929, 1885654, 1571378, 1257102, 942827, 628551, 314275],
    "Species Indicator": [0.7543, 0.7457, 0.7534, 0.7491, 0.7466, 0.7443, 0.7456, 0.7431, 0.7487, 0.7489, 0.7502],
    "Old Growth Indicator": [303678.5, 580504.3, 334075.7, 364650.4, 393684.8, 423066.2, 451206.5, 479354.5, 505137.4, 530289.9, 556633.9]
}


equitysilver_max_st = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    # "Carbon Stock": [1.993899100e+08, 2.213324476e+08, 2.023201210e+08, 2.049510923e+08, 2.073555872e+08,
    #                  2.0959373e+08, 2.1161157e+08, 2.1346753e+08, 2.1511490e+08, 2.1654530e+08, 2.1772600e+08],
    "Net Emissions": [-34255783, -117907115, -49672695, -64270430, -78526028, -91980728, -104984288, -117144321,
                      -128555316, -139248380, -148466128],
    "Social Indicator": [92157, 42718, 83272, 74497, 65185, 55858, 46351, 37113, 27854, 18498, 9293],
    "Economic Indicator": [3142756, 1456798, 2839766, 2540532, 2222965, 1904896, 1580700, 1265647, 949882,
                                630844, 316931],
    "Species Indicator": [0.7534, 0.7618, 0.7507, 0.7484, 0.7441, 0.7440, 0.7438, 0.7428, 0.7419, 0.7425,
                                     0.7429],
    "Old Growth Indicator": [317668.7, 556478.12, 343022.16, 366396.3, 390767.51, 417504.07, 445561.57,
                                            473603.09, 500597.34, 526910.75, 552527.14]
}

equitysilver_min_em = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    # "Net Emission": [-8.4556995e+07, -1.6051199e+08, -9.6237592e+07, -1.0688514e+08, -1.1650972e+08,
    #                  -1.2533166e+08, -1.3318654e+08, -1.4030201e+08, -1.466282322e+08, -1.5177528e+08,
    #                  -1.549826706e+08],
    "Net Emissions": [-33180983, -151871771, -48819211, -63980807, -78384629, -92468485, -105856916,
                      -118833104, -130275827, -140664223, -148892042],
    "Social Indicator": [92157, 13888, 82941, 73725, 64510, 55294, 46078, 36862, 27647, 18443, 9408],
    "Economic Indicator": [3142756, 473621, 2828481, 2514205, 2199929, 1885654, 1571378, 1257102, 942827,
                                628976, 320857],
    "Species Indicator": [0.7258, 0.7421, 0.7137, 0.7063, 0.6987, 0.6929, 0.6930, 0.6971, 0.7071, 0.7228,
                                     0.7373],
    "Old Growth Indicator": [214539.2, 516820.07, 242967.94, 275445.01, 311282.5, 349133.9, 384958.37,
                                            422547.95, 459147.55, 498725.47, 538769.88]
}

# %%
# Plot each objective mode seperately for each case study
case_studies = ['redchris', 'goldenbear', 'equitysilver']
obj_modes = ['Max_hv', 'Min_ha', 'Max_st', 'Min_em',]
data_sets = {
    "equitysilver_max_hv": equitysilver_max_hv,
    "equitysilver_min_em": equitysilver_min_em,
    "equitysilver_max_st": equitysilver_max_st,
    "equitysilver_min_ha": equitysilver_min_ha
}

case_study_widget = widgets.Dropdown(
    options=case_studies,
    description="Case Study:",
    value='equitysilver'
)

obj_mode_widget = widgets.Dropdown(
    options=obj_modes,
    description="Objective Mode:",
    value='Max_hv'
)

def update_chart(case_study, obj_mode):
    # Construct variable name dynamically
    data_var_name = f"{case_study}_{obj_mode}".lower()
    try:
        # Dynamically access the dataset based on the constructed variable name
        data = globals()[data_var_name]
        generate_radar_chart(data=data, case_study=case_study, obj_mode=obj_mode)
    except KeyError:
        print(f"Dataset for {data_var_name} not found. Please ensure it is defined.")

interact(update_chart, case_study=case_study_widget, obj_mode=obj_mode_widget)
# Out:
# interactive(children=(Dropdown(description='Case Study:', index=2, options=('redchris', 'goldenbear', 'equitys…
# <function __main__.update_chart(case_study, obj_mode)>

# %%
# Plot all objective modes for each case study
case_studies = ['redchris', 'goldenbear', 'equitysilver']
obj_modes = ['Max_hv', 'Min_ha', 'Max_st', 'Min_em']

data_sets = {
    "equitysilver_max_hv": equitysilver_max_hv,
    "equitysilver_min_em": equitysilver_min_em,
    "equitysilver_max_st": equitysilver_max_st,
    "equitysilver_min_ha": equitysilver_min_ha
}

# Create the dropdown widget for user selection
case_study_widget = widgets.Dropdown(
    options=case_studies,
    description="Case Study:",
    value='equitysilver'
)

# Update function for generating subplots
def update_subplots_chart(case_study):
    generate_subplots_radar_chart(case_study, obj_modes, data_sets)

# Create the interactive widget
interact(update_subplots_chart, case_study=case_study_widget, obj_modes=obj_modes)
# Out:
# interactive(children=(Dropdown(description='Case Study:', index=2, options=('redchris', 'goldenbear', 'equitys…
# <function __main__.update_subplots_chart(case_study)>

# %% [markdown]
# # Indicators

# %%
# Data dictionaries
equitysilver_net_emission = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    "Max_hv": [-10187414, 2860992, -20190655, -37717399, -53571451, -69020879, -83747319, -96901488, -116527826, -127261518, -141630206],
    "Min_ha": [-27541849, -155624647, -42297895, -55475110, -69237782, -83282990, -96462861, -109037924, -121829519, -133928525, -144780424],
    "Max_st": [-34255783, -117907115, -49672695, -64270430, -78526028, -91980728, -104984288, -117144321, -128555316, -139248380, -148466128],
    "Min_em": [-33180983, -151871771, -48819211, -63980807, -78384629, -92468485, -105856916, -118833104, -130275827, -140664223, -148892042]
}

equitysilver_social = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    "Max_hv": [100842, 141080, 90757, 80673, 70589, 60505, 50421, 40336, 30252, 20168, 10084],
    "Min_ha": [92157, None, 82941, 73725, 64510, 55294, 46078, 36862, 27647, 18431, 9215],
    "Max_st": [92157, 42718, 83272, 74497, 65185, 55858, 46351, 37113, 27854, 18498, 9293],
    "Min_em": [92157, 13888, 82941, 73725, 64510, 55294, 46078, 36862, 27647, 18443, 9408]
}

equitysilver_economic = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    "Max_hv": [3438933, 4811151, 3095039, 2751146, 2407253, 2063360, 1719466, 1375573, 1031680, 687786, 343893],
    "Min_ha": [3142756, None, 2828481, 2514205, 2199929, 1885654, 1571378, 1257102, 942827, 628551, 314275],
    "Max_st": [3142756, 1456798, 2839766, 2540532, 2222965, 1904896, 1580700, 1265647, 949882, 630844, 316931],
    "Min_em": [3142756, 473621, 2828481, 2514205, 2199929, 1885654, 1571378, 1257102, 942827, 628976, 320857]
}

equitysilver_species = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    "Max_hv": [0.7329, 0.7509, 0.7607, 0.7514, 0.7445, 0.7401, 0.7375, 0.7275, 0.7328, 0.7365, 0.7399],
    "Min_ha": [0.7543, 0.7457, 0.7534, 0.7491, 0.7466, 0.7443, 0.7456, 0.7431, 0.7487, 0.7489, 0.7502],
    "Max_st": [0.7534, 0.7618, 0.7507, 0.7484, 0.7441, 0.7440, 0.7438, 0.7428, 0.7419, 0.7425, 0.7429],
    "Min_em": [0.7258, 0.7421, 0.7137, 0.7063, 0.6987, 0.6929, 0.6930, 0.6971, 0.7071, 0.7228, 0.7373]
}
equitysilver_old = {
    "Scenarios": ["Baseline", "S0", "S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9"],
    "Max_hv": [196384, 166327, 222922.6, 247449, 286878.4, 324882.5, 367419, 420221.3, 462754.7, 502643, 535463.1],
    "Min_ha": [303678.5, 580504.3, 334075.7, 364650.4, 393684.8, 423066.2, 451206.5, 479354.5, 505137.4, 530289.9, 556633.9],
    "Max_st": [317668.7, 556478.12, 343022.16, 366396.3, 390767.51, 417504.07, 445561.57,
                                            473603.09, 500597.34, 526910.75, 552527.14],
    "Min_em": [214539.2, 516820.07, 242967.94, 275445.01, 311282.5, 349133.9, 384958.37,
                                            422547.95, 459147.55, 498725.47, 538769.88]
}

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact

# Function to create grouped bar charts
def create_grouped_bar_chart(data, y_label, case_study):
    # Extract scenarios and objective modes
    scenarios = data["Scenarios"]
    modes = list(data.keys())[1:]  # Exclude "Scenarios"

    # Prepare data
    values = [data[mode] for mode in modes]
    x = np.arange(len(scenarios))  # X locations for the groups
    width = 0.8 / len(modes)  # Width of each bar

    # Create the plot
    fig, ax = plt.subplots(figsize=(14, 6))
    for i, mode in enumerate(modes):
        # Extract the i-th mode's values for all scenarios
        mode_values = [value if value is not None else 0 for value in values[i]]
        ax.bar(x + i * width, mode_values, width, label=mode)

    # Add labels, title, and legend
    ax.set_xticks(x + (len(modes) - 1) * width / 2)
    ax.set_xticklabels(scenarios, rotation=45, ha="right", fontsize=10)
    ax.set_ylabel(y_label, fontsize=12)
    ax.legend(title="Objectives", fontsize=9)

    # Save the plot
    plt.tight_layout()
    output_dir = f'./plots/fig/{case_study}'
    os.makedirs(output_dir, exist_ok=True)
    file_name = f"{case_study}_{y_label}_indicators_subplots.svg"
    file_path = os.path.join(output_dir, file_name)
    plt.savefig(file_path, format='svg')
    plt.show()

# Datasets for different case studies
datasets = {
    "equitysilver": {
        "Net Emissions (ton)": equitysilver_net_emission,
        "Number of Jobs": equitysilver_social,
        "Revenue ($)": equitysilver_economic,
        "Shannon Index Value": equitysilver_species,
        "Old Growth Area (hectare)": equitysilver_old
    },
    # "goldenbear": {
    #     "Net Emissions (ton)": goldenbear_net_emission,
    #     "Number of Jobs": goldenbear_social,
    #     "Revenue ($)": goldenbear_economic,
    #     "Shannon Index Value": goldenbear_species,
    #     "Old Growth Area (hectare)": goldenbear_old
    # },
    # "redchris": {
    #     "Net Emissions (ton)": redchris_net_emission,
    #     "Number of Jobs": redchris_social,
    #     "Revenue ($)": redchris_economic,
    #     "Shannon Index Value": redchris_species,
    #     "Old Growth Area (hectare)": redchris_old
    # }
}

# Dropdown widget for y-labels
y_label_widget = widgets.Dropdown(
    options=list(datasets["equitysilver"].keys()),  # Default to equitysilver indicators
    description="Indicator:",
    value="Net Emissions (ton)"
)

# Dropdown widget for case studies
case_study_widget = widgets.Dropdown(
    options=datasets.keys(),
    description="Case Study:",
    value="equitysilver"
)

# Update function for interactive plots
def update(case_study, y_label):
    # Update available indicators based on the selected case study
    y_label_widget.options = list(datasets[case_study].keys())
    data = datasets[case_study][y_label]
    create_grouped_bar_chart(data, y_label, case_study)

# Create interactive widget
interact(update, case_study=case_study_widget, y_label=y_label_widget)
# Out:
# interactive(children=(Dropdown(description='Case Study:', options=('equitysilver',), value='equitysilver'), Dr…
# <function __main__.update(case_study, y_label)>

# %%
# create_grouped_bar_chart(equitysilver_net_emission, "Net Emissions (ton)", case_study= 'equitysilver')
# create_grouped_bar_chart(equitysilver_social, "Number of Jobs", case_study= 'equitysilver')
# create_grouped_bar_chart(equitysilver_economic, "Revenue ($)", case_study= 'equitysilver')
# create_grouped_bar_chart(equitysilver_species, "Shannon Index Value", case_study= 'equitysilver')
# create_grouped_bar_chart(equitysilver_old, "Area (hectare)", case_study= 'equitysilver')

# %% [raw]
# # Comparing KPIs of scenarios under each obj _mode
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Function to create grouped bar chart
# def create_grouped_bar_chart(data, title):
#     # Extract metrics and scenarios
#     metrics = list(data.keys())[1:]  # Exclude "Scenarios"
#     scenarios = data["Scenarios"]
#
#     # Prepare data
#     values = [data[metric] for metric in metrics]
#     x = np.arange(len(metrics))  # X locations for the groups
#     width = 0.8 / len(scenarios)  # Width of each bar
#
#     # Create the plot
#     fig, ax = plt.subplots(figsize=(12, 6))
#     for i, scenario in enumerate(scenarios):
#         # Extract the i-th values for all metrics
#         scenario_values = [value[i] if value[i] is not None else 0 for value in values]
#         ax.bar(x + i * width, scenario_values, width, label=scenario)
#
#     # Add labels, title, and legend
#     ax.set_xticks(x + (len(scenarios) - 1) * width / 2)
#     ax.set_xticklabels(metrics, rotation=45, ha="right", fontsize=10)
#     ax.set_ylabel("Values", fontsize=12)
#     ax.set_title(title, fontsize=14)
#     ax.legend(title="Scenarios", fontsize=9)
#
#     # Adjust layout and display the plot
#     plt.tight_layout()
#     plt.show()
#
# # Generate grouped bar charts for each dictionary
# create_grouped_bar_chart(equitysilver_net_emission, "Net Emissions Across Scenarios")
# create_grouped_bar_chart(equitysilver_social, "Social Indicators Across Scenarios")
# create_grouped_bar_chart(equitysilver_economic, "Economic Indicators Across Scenarios")
# create_grouped_bar_chart(equitysilver_species, "Species Indicators Across Scenarios")
# create_grouped_bar_chart(equitysilver_old, "Old Growth Indicators Across Scenarios")
