# %% [markdown]
# # Connect Forest Management Model with Forest Carbon Budget Model (without calibration)

# %% [markdown]
# ## Set up Modelling Environment

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import ws3.forest
import time
import gurobipy as grb
import pickle
import libcbm
import os
from util_opt import compile_events, cbm_report, compile_scenario_maxstock, plot_scenario_maxstock, run_cbm_emissionstock, run_scenario, plugin_c_curves, plugin_c_curves_both, cbm_report_both, compare_ws3_cbm, compare_ws3_cbm_both, track_system_stock, track_system_emission, compile_scenario_minemission, plot_scenario_minemission, kpi_age, kpi_species, cmp_c_ss, cmp_c_se, results_scenarios, bootstrap_ogi, compare_kpi_age

# %%
base_year = 2020
horizon = 10
period_length = 10
max_age = 1000
n_steps = 100
tvy_name = 'totvol'
max_harvest = 1.0

# %%
# Define scenario options based on case study
scenario_options = {
    'redchris': ['no_cons','evenflow_cons',  'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

# Function to handle case study selection and update scenario dropdown
def select_case_study(case_study):
    print(f"Selected case study: {case_study}")
    # Update the scenario dropdown based on the selected case study
    scenario_dropdown.options = scenario_options.get(case_study, [])
    scenario_dropdown.value = scenario_options[case_study][0]  # Set a default value

# Case study dropdown
case_study_dropdown = widgets.Dropdown(
    options=['redchris', 'goldenbear', 'equitysilver', 'test'],
    value='redchris',
    description='Case Study:'
)
case_study_dropdown.observe(lambda change: select_case_study(change['new']), names='value')
display(case_study_dropdown)

# Function to handle scenario selection
def select_scenario(scenario_name):
    print(f"Selected scenario: {scenario_name}")

# Scenario dropdown
scenario_dropdown = widgets.Dropdown(
    options=scenario_options['redchris'],  # Set initial options based on default case study
    value=scenario_options['redchris'][1],  # Set initial value
    description='Scenario:'
)
scenario_dropdown.observe(lambda change: select_scenario(change['new']), names='value')
display(scenario_dropdown)

# Function to handle objective functon
def select_obj(obj_mode):
    print(f"Selected objective: {obj_mode}")
obj_dropdown = widgets.Dropdown(
    options=['max_hv', 'min_ha', 'max_st', 'min_em'],
    value='max_hv',
    description='Objective:'
)
display(obj_dropdown)
obj_dropdown.observe(lambda change: select_obj(change['new']), names='value')
# Out:
# Dropdown(description='Case Study:', options=('redchris', 'goldenbear', 'equitysilver', 'test'), value='redchri…
# Dropdown(description='Scenario:', index=1, options=('no_cons', 'evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90…
# Dropdown(description='Objective:', index=2, options=('max_hv', 'min_ha', 'max_st', 'min_em'), value='max_st')

# %%
# Initialize main widget components 
hwp_pool_effect = widgets.FloatSlider(min=0, max=1, step=1, description='HWP_effect', value=1, layout=widgets.Layout(margin='10px 0'))
release_immediately = widgets.FloatSlider(min=0, max=1, step=1, description='Release immediately', value=1, layout=widgets.Layout(margin='10px 0'))
displacement_effect = widgets.FloatSlider(min=0, max=1, step=1, description='Displacement', value=1, layout=widgets.Layout(margin='10px 0'))
clt_percentage = widgets.FloatSlider(min=0, max=1, step=0.1, description='CLT_percent:', value=0.5, layout=widgets.Layout(margin='10px 0'))
credibility = widgets.FloatSlider(min=0, max=1, step=0.1, description='Credibility:', value=1, layout=widgets.Layout(margin='10px 0'))
# max_harvest = widgets.FloatSlider(min=0, max=1, step=0.05, description='Max_harvest:', value=1.0, layout=widgets.Layout(margin='10px 0'))
budget_input = widgets.FloatText(value=10000000, description='Budget:', layout=widgets.Layout(margin='10px 0'))

release_immediately.layout.display = 'none' if hwp_pool_effect.value != 0 else 'block'
displacement_effect.layout.display = 'block' if hwp_pool_effect.value != 0 else 'none'
clt_percentage.layout.display = 'block' if hwp_pool_effect.value != 0 and displacement_effect.value != 0 else 'none'
credibility.layout.display = 'block' if hwp_pool_effect.value != 0 and displacement_effect.value != 0 else 'none'

container = widgets.VBox([
    hwp_pool_effect, release_immediately, displacement_effect, clt_percentage, credibility, budget_input  
    # ,max_harvest
])

display(container)

def update_widgets(change):
    hwp_pool_effect_value = hwp_pool_effect.value
    displacement_effect_value = displacement_effect.value

    release_immediately.layout.display = 'block' if hwp_pool_effect_value == 0 else 'none'
    displacement_effect.layout.display = 'block' if hwp_pool_effect_value != 0 else 'none'

    clt_percentage.layout.display = 'block' if hwp_pool_effect_value != 0 and displacement_effect_value != 0 else 'none'
    credibility.layout.display = 'block' if hwp_pool_effect_value != 0 and displacement_effect_value != 0 else 'none'

hwp_pool_effect.observe(update_widgets, names='value')
displacement_effect.observe(update_widgets, names='value')
# Out:
# VBox(children=(FloatSlider(value=1.0, description='HWP_effect', layout=Layout(margin='10px 0'), max=1.0, step=…

# %%
#Start Calculating the Running Time
Start = time.time()

# %%
case_study = case_study_dropdown.value
scenario_name = scenario_dropdown.value
obj_mode = obj_dropdown.value
hwp_pool_effect_value = hwp_pool_effect.value
release_immediately_value = release_immediately.value if hwp_pool_effect_value == 0 else 0
displacement_effect = displacement_effect.value if hwp_pool_effect_value != 0 else 0
clt_percentage = clt_percentage.value if displacement_effect != 0 else 0
credibility = credibility.value if displacement_effect != 0 else 0
# max_harvest = max_harvest.value
budget_input = budget_input.value

# %%
# Define case study mappings and retrieve model details based on case study
case_study_options = {
    'redchris': {
        'model_name': 'redchris',
        'model_path': './data/woodstock_model_files_redchris'
    },
    'goldenbear': {
        'model_name': 'goldenbear',
        'model_path': './data/woodstock_model_files_goldenbear'
    },
    'equitysilver': {
        'model_name': 'equitysilver',
        'model_path': './data/woodstock_model_files_equitysilver'
    },
    'test': {
        'model_name': 'redchris',
        'model_path': './data/woodstock_model_files_redchris_test'
    }
}

model_info = case_study_options.get(case_study)

if model_info:
    model_name = model_info['model_name']
    model_path = model_info['model_path']
else:
    print('The case study name is not valid')

# %%
# Create and Run `ForestModel` instance
fm = ws3.forest.ForestModel(model_name=model_name,
                            model_path=model_path,
                            base_year=base_year,
                            horizon=horizon,
                            period_length=period_length,
                            max_age=max_age)
fm.import_landscape_section()
fm.import_areas_section()
fm.import_yields_section()
fm.import_actions_section()
fm.import_transitions_section()
fm.initialize_areas()
fm.add_null_action()
fm.reset_actions()
fm.grow()

# %%
# Flag 'harvest' as a harvesting action in the ws3 model
harvest_acode='harvest'
fm.actions[harvest_acode].is_harvest = True

# %%
# Read curves
file_directory = "./inputs/curves"
file_names = [f"{case_study}_c_curves_p.pkl", f"{case_study}_c_curves_f.pkl"]
loaded_data = {}

for filename in file_names:
    file_path = os.path.join(file_directory, filename)
    with open(file_path, 'rb') as file:
        loaded_data[filename] = pickle.load(file)
    print(f"Loaded data from {file_path}")

c_curves_p = loaded_data.get(f"{case_study}_c_curves_p.pkl")
c_curves_f = loaded_data.get(f"{case_study}_c_curves_f.pkl")
# Out:
# Loaded data from ./inputs/curves/redchris_c_curves_p.pkl
# Loaded data from ./inputs/curves/redchris_c_curves_f.pkl

# %%
# Plug carbon and old groth yield curves into forest model
plugin_c_curves_both(fm, c_curves_p, c_curves_f)
bootstrap_ogi(fm)

# %%
Start = time.time()
scenario_names = scenario_options.get(case_study, [])
for scenario_name in scenario_names:
    print(f"Running for {case_study}_{obj_mode}_{scenario_name}...")
    results_scenarios(fm, 
                      clt_percentage, 
                      credibility, 
                      budget_input, 
                      n_steps, 
                      max_harvest, 
                      scenario_name, 
                      displacement_effect, 
                      hwp_pool_effect_value, 
                      release_immediately_value, 
                      case_study, 
                      obj_mode,                   
                      pickle_output_base=False, 
                      pickle_output_alter=False)
print('It took', round((time.time() - Start) / 60, 1), "minutes to run all scenarios.")
# Out:
# Running for redchris_max_hv_no_cons...
# running test scenario
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3667 rows, 34533 columns and 34533 nonzeros
# Model fingerprint: 0x38763cd3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 3667 rows and 34533 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0063889e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.01 work units)
# Optimal objective  3.006388928e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_no_cons_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_no_cons_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688   4909.785142   3964.471454
# Pine     602.782616   1505.321386    902.538770
# Bal     4315.588546  27951.218565  23635.630019
# Spruce  1072.814408  12878.635366  11805.820959
#
# Overall diversity has **increased** by 40308.46 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_no_cons_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0354
# Pine: 0.0376
# Bal: 0.4459
# Spruce: 0.4811
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.6880
#
# Diversity has **decreased** by 19.68% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_no_cons_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.13s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#    5   1.35642935e+07  1.92833004e+07  2.16e+01 6.72e+00  1.76e+02     0s
#
# Barrier performed 5 iterations in 0.32 seconds (0.25 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.36 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference 4452463.075722149
# Net emission base scenario -6526453.067051755
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  2.2459478787206093
# Comparison of Old Growth Areas (Alternative - Base)
#           0            10    Difference
# Aspen   0.0  -8377.198989  -8377.198989
# Pine    0.0  -5675.665026  -5675.665026
# Bal     0.0 -19941.541760 -19941.541760
# Spruce  0.0 -19162.296554 -19162.296554
#
# Overall, the old growth area has **decreased** by -53156.70 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_evenflow_cons...
# running no constraints scenario
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3707 rows, 34533 columns and 445161 nonzeros
# Model fingerprint: 0x5ba631eb
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2009 rows and 3667 columns
# Presolve time: 0.09s
# Presolved: 1698 rows, 30866 columns, 413674 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.923e+04
#  Factor NZ  : 8.016e+04 (roughly 14 MB of memory)
#  Factor Ops : 3.924e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.38750616e+08 -0.00000000e+00  5.33e+03 2.18e+04  3.94e+04     0s
#    1   5.23745737e+08  1.00331920e+06  2.82e+03 1.96e+04  2.52e+04     0s
#    2   4.46802260e+08  2.90568721e+07  2.36e+03 1.31e+04  2.15e+04     0s
#    3   9.38349754e+07  7.71776103e+07  3.77e+02 1.98e+03  4.66e+03     0s
#    4   5.68186521e+07  6.72355275e+07  1.80e+02 1.12e+03  2.44e+03     0s
#    5   4.93277174e+07  5.34913882e+07  1.40e+02 5.76e+02  1.70e+03     0s
#    6   3.81892627e+07  4.36446417e+07  7.99e+01 3.30e+02  9.94e+02     0s
#    7   2.95125778e+07  3.72214385e+07  3.14e+01 1.83e+02  5.12e+02     0s
#    8   2.72043464e+07  3.09444502e+07  1.69e+01 7.73e+01  2.67e+02     0s
#    9   2.47282769e+07  2.87370941e+07  2.60e+00 4.46e+01  1.36e+02     0s
#   10   2.42411704e+07  2.66844214e+07  1.28e+00 2.17e+01  6.88e+01     0s
#   11   2.42806141e+07  2.61929920e+07  9.12e-01 1.69e+01  5.08e+01     0s
#   12   2.43701939e+07  2.58179821e+07  5.97e-01 1.28e+01  3.59e+01     0s
#   13   2.44589284e+07  2.54610752e+07  4.26e-01 8.33e+00  2.45e+01     0s
#   14   2.45682082e+07  2.52460925e+07  2.85e-01 5.34e+00  1.63e+01     0s
#   15   2.47184497e+07  2.50786877e+07  1.40e-01 2.37e+00  8.29e+00     0s
#   16   2.48036105e+07  2.50417945e+07  8.47e-02 1.59e+00  5.33e+00     0s
#   17   2.48962205e+07  2.50162455e+07  3.85e-02 7.56e-01  2.60e+00     0s
#   18   2.49175865e+07  2.50086136e+07  2.92e-02 5.50e-01  1.97e+00     0s
#   19   2.49646140e+07  2.49985834e+07  1.02e-02 2.01e-01  7.18e-01     0s
#   20   2.49857607e+07  2.49957606e+07  2.59e-03 8.65e-02  2.07e-01     0s
#   21   2.49934668e+07  2.49941063e+07  7.07e-05 1.05e-02  1.21e-02     0s
#   22   2.49937468e+07  2.49938791e+07  9.32e-06 3.50e-03  2.47e-03     0s
#   23   2.49937978e+07  2.49938100e+07  1.74e-07 5.68e-04  2.25e-04     0s
#   24   2.49937990e+07  2.49938018e+07  2.76e-08 1.31e-04  5.20e-05     0s
#
# Barrier performed 24 iterations in 0.42 seconds (0.35 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4223    2.4993799e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 4223 iterations and 0.46 seconds (0.85 work units)
# Optimal objective  2.499379927e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_evenflow_cons_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_evenflow_cons_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688   4909.785142   3964.471454
# Pine     602.782616   1505.321386    902.538770
# Bal     4315.588546  27951.218565  23635.630019
# Spruce  1072.814408  12878.635366  11805.820959
#
# Overall diversity has **increased** by 40308.46 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_evenflow_cons_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0588
# Pine: 0.0395
# Bal: 0.4362
# Spruce: 0.4656
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7300
#
# Diversity has **decreased** by 15.48% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_evenflow_cons_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.17s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#    5   1.35642935e+07  1.92833004e+07  2.16e+01 6.72e+00  1.76e+02     0s
#
# Barrier performed 5 iterations in 0.32 seconds (0.25 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.36 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference 3223635.098854569
# Net emission base scenario -7755281.043919334
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  3.10208807552481
# Comparison of Old Growth Areas (Alternative - Base)
#           0            10    Difference
# Aspen   0.0  -8377.198989  -8377.198989
# Pine    0.0  -5675.665026  -5675.665026
# Bal     0.0 -19941.541760 -19941.541760
# Spruce  0.0 -19162.296554 -19162.296554
#
# Overall, the old growth area has **decreased** by -53156.70 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_bau_redchrs...
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.13s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#    5   1.35642935e+07  1.92833004e+07  2.16e+01 6.72e+00  1.76e+02     0s
#
# Barrier performed 5 iterations in 0.28 seconds (0.25 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.32 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.11s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#
# Barrier performed 4 iterations in 0.26 seconds (0.24 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.30 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# /media/data/project/eghasemi/nbds_mining/util_opt.py:1185: RuntimeWarning: divide by zero encountered in scalar divide
#   dollar_per_ton = abs(budget_input / dif_scenario.iloc[:25]['Net emission'].sum())
# Net emission difference 0.0
# Net emission base scenario -10978916.142773904
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  inf
# Comparison of Old Growth Areas (Alternative - Base)
#           0   10  Difference
# Aspen   0.0  0.0         0.0
# Pine    0.0  0.0         0.0
# Bal     0.0  0.0         0.0
# Spruce  0.0  0.0         0.0
#
# Overall, the old growth area has **increased** by 0.00 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_redchrs_AAC_90%...
# running the scenario for the Red Chris mining site (90%_AAC),
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x63014774
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.16s
# Presolved: 1699 rows, 30867 columns, 420630 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.08629288e+09  2.78903109e+00  2.59e+04 2.18e+04  1.90e+05     0s
#    1   3.40240347e+09  2.01950291e+07  2.16e+04 7.56e+03  1.57e+05     0s
#    2   5.47691711e+08  5.34694385e+07  3.42e+03 1.15e-10  2.61e+04     0s
#
# Barrier performed 2 iterations in 0.28 seconds (0.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      841    1.0090259e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 841 iterations and 0.33 seconds (0.39 work units)
# Optimal objective  1.009025875e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_90%_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_90%_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13577.035221  12631.721533
# Pine     602.782616   7310.907227   6708.124611
# Bal     4315.588546  49372.562958  45056.974412
# Spruce  1072.814408  34215.209124  33142.394716
#
# Overall diversity has **increased** by 97539.22 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_90%_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0714
# Pine: 0.0582
# Bal: 0.4235
# Spruce: 0.4469
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7774
#
# Diversity has **decreased** by 10.75% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_90%_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.12s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#    5   1.35642935e+07  1.92833004e+07  2.16e+01 6.72e+00  1.76e+02     0s
#    6   1.12994840e+07  1.27734189e+07  8.09e-01 9.24e-01  2.53e+01     0s
#
# Barrier performed 6 iterations in 0.30 seconds (0.26 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.34 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference -469159.5617574438
# Net emission base scenario -11448075.70453135
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  21.314709994485874
# Comparison of Old Growth Areas (Alternative - Base)
#           0           10   Difference
# Aspen   0.0   290.051090   290.051090
# Pine    0.0   129.920814   129.920814
# Bal     0.0  1479.802633  1479.802633
# Spruce  0.0  2174.277203  2174.277203
#
# Overall, the old growth area has **increased** by 4074.05 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_redchrs_AAC_80%...
# running the scenario for the Red Chris mining site (80%_AAC),
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x47cc0108
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.12s
# Presolved: 1699 rows, 30867 columns, 420630 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.79844862e+09  2.78914356e+00  2.41e+04 2.18e+04  1.76e+05     0s
#
# Barrier performed 0 iterations in 0.23 seconds (0.21 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      649    8.9691200e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 649 iterations and 0.27 seconds (0.36 work units)
# Optimal objective  8.969120050e+06
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_80%_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_80%_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13992.917391  13047.603703
# Pine     602.782616   7969.452841   7366.670225
# Bal     4315.588546  49475.202912  45159.614366
# Spruce  1072.814408  35402.542006  34329.727598
#
# Overall diversity has **increased** by 99903.62 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_80%_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0711
# Pine: 0.0621
# Bal: 0.4172
# Spruce: 0.4496
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7825
#
# Diversity has **decreased** by 10.24% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_80%_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.14s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
# Barrier performed 0 iterations in 0.30 seconds (0.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.37 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference -754500.8083509111
# Net emission base scenario -11733416.951124813
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  13.253796270751105
# Comparison of Old Growth Areas (Alternative - Base)
#           0           10   Difference
# Aspen   0.0   705.933260   705.933260
# Pine    0.0   788.466428   788.466428
# Bal     0.0  1582.442588  1582.442588
# Spruce  0.0  3361.610086  3361.610086
#
# Overall, the old growth area has **increased** by 6438.45 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_redchrs_AAC_70%...
# running the scenario for the Red Chris mining site (70%_AAC),
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0xfb1596fd
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.15s
# Presolved: 1699 rows, 30867 columns, 420630 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
# Barrier performed 0 iterations in 0.29 seconds (0.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      547    7.8479813e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 547 iterations and 0.33 seconds (0.36 work units)
# Optimal objective  7.847981350e+06
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_70%_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_70%_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  14276.748119  13331.434431
# Pine     602.782616   8905.683793   8302.901177
# Bal     4315.588546  50667.660346  46352.071800
# Spruce  1072.814408  37141.235415  36068.421008
#
# Overall diversity has **increased** by 104054.83 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_70%_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0702
# Pine: 0.0648
# Bal: 0.4197
# Spruce: 0.4453
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7852
#
# Diversity has **decreased** by 9.97% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_70%_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.14s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#
# Barrier performed 4 iterations in 0.30 seconds (0.24 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.34 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference -1294369.284985615
# Net emission base scenario -12273285.427759519
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  7.725770470605021
# Comparison of Old Growth Areas (Alternative - Base)
#           0           10   Difference
# Aspen   0.0   989.763988   989.763988
# Pine    0.0  1724.697381  1724.697381
# Bal     0.0  2774.900021  2774.900021
# Spruce  0.0  5100.303495  5100.303495
#
# Overall, the old growth area has **increased** by 10589.66 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_redchrs_AAC_60%...
# running the scenario for the Red Chris mining site (60%_AAC),
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x7c10d97b
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.14s
# Presolved: 1699 rows, 30867 columns, 420630 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
# Barrier performed 0 iterations in 0.23 seconds (0.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      373    6.7268427e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 373 iterations and 0.26 seconds (0.31 work units)
# Optimal objective  6.726842650e+06
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_60%_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_60%_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13978.117263  13032.803575
# Pine     602.782616   9168.440555   8565.657938
# Bal     4315.588546  51385.129954  47069.541408
# Spruce  1072.814408  39613.459781  38540.645373
#
# Overall diversity has **increased** by 107208.65 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_60%_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0666
# Pine: 0.0643
# Bal: 0.4056
# Spruce: 0.4635
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7786
#
# Diversity has **decreased** by 10.62% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_60%_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.12s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#
# Barrier performed 4 iterations in 0.28 seconds (0.24 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.32 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# ...
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.36 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference -3065617.779989177
# Net emission base scenario -14044533.92276308
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  3.2619852563731233
# Comparison of Old Growth Areas (Alternative - Base)
#           0           10   Difference
# Aspen   0.0  7561.011388  7561.011388
# Pine    0.0  2208.999860  2208.999860
# Bal     0.0  4849.190308  4849.190308
# Spruce  0.0  9713.322549  9713.322549
#
# Overall, the old growth area has **increased** by 24332.52 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_redchrs_AAC_20%...
# running the scenario for the Red Chris mining site (20%_AAC),
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x8ce551ef
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.13s
# Presolved: 1699 rows, 30867 columns, 420630 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
# Barrier performed 0 iterations in 0.23 seconds (0.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       78    2.2422878e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 78 iterations and 0.26 seconds (0.25 work units)
# Optimal objective  2.242287850e+06
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_20%_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_20%_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  23525.257196  22579.943508
# Pine     602.782616   9389.986273   8787.203656
# Bal     4315.588546  53579.735001  49264.146455
# Spruce  1072.814408  41791.198387  40718.383979
#
# Overall diversity has **increased** by 121349.68 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_20%_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0760
# Pine: 0.0566
# Bal: 0.4105
# Spruce: 0.4569
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.44% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_20%_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.13s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#
# Barrier performed 4 iterations in 0.27 seconds (0.24 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.32 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference -3736976.4522003373
# Net emission base scenario -14715892.59497424
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  2.6759601319168027
# Comparison of Old Growth Areas (Alternative - Base)
#           0            10    Difference
# Aspen   0.0  10238.273065  10238.273065
# Pine    0.0   2208.999860   2208.999860
# Bal     0.0   5686.974676   5686.974676
# Spruce  0.0   9750.266467   9750.266467
#
# Overall, the old growth area has **increased** by 27884.51 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# Running for redchris_max_hv_redchrs_AAC_10%...
# running the scenario for the Red Chris mining site (10%_AAC),
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0xfd7d3b40
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.14s
# Presolved: 1699 rows, 30867 columns, 420630 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
# Barrier performed 0 iterations in 0.23 seconds (0.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       72    1.1211492e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 72 iterations and 0.30 seconds (0.25 work units)
# Optimal objective  1.121149150e+06
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_10%_scheduling.pdf
# Saved cbm_output_1 and cbm_output_2 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_10%_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  34157.749172  33212.435484
# Pine     602.782616   9389.986273   8787.203656
# Bal     4315.588546  54087.103674  49771.515128
# Spruce  1072.814408  41544.331677  40471.517269
#
# Overall diversity has **increased** by 132242.67 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_10%_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0930
# Pine: 0.0551
# Bal: 0.4093
# Spruce: 0.4426
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7985
#
# Diversity has **decreased** by 8.63% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_redchrs_AAC_10%_species_pie.pdf
# running business as usual scenario for the Red Chris mining site,
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: Intel Core Processor (Broadwell, IBRS), instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 3711 rows, 34533 columns and 483527 nonzeros
# Model fingerprint: 0x4976d622
# Coefficient statistics:
#   Matrix range     [1e-02, 4e+06]
#   Objective range  [3e+00, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2012 rows and 3667 columns
# Presolve time: 0.12s
# Presolved: 1699 rows, 30866 columns, 420629 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.066e+04
#  Factor NZ  : 8.155e+04 (roughly 14 MB of memory)
#  Factor Ops : 4.060e+06 (less than 1 second per iteration)
#  Threads    : 14
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.18033153e+09  1.07402576e+07  1.99e+04 1.63e+04  9.54e+04     0s
#    1   1.22935996e+09  4.48405500e+07  1.12e+04 1.87e+03  5.27e+04     0s
#    2   7.11133727e+07  5.00529313e+07  5.49e+02 2.40e+02  3.15e+03     0s
#    3   3.21557992e+07  3.85568816e+07  1.92e+02 7.50e+01  1.20e+03     0s
#    4   1.94427269e+07  2.39737488e+07  7.55e+01 1.39e+01  4.15e+02     0s
#    5   1.35642935e+07  1.92833004e+07  2.16e+01 6.72e+00  1.76e+02     0s
#    6   1.12994840e+07  1.27734189e+07  8.09e-01 9.24e-01  2.53e+01     0s
#    7   1.12113849e+07  1.12179200e+07  2.05e-12 0.00e+00  1.03e-01     0s
#    8   1.12113870e+07  1.12113935e+07  1.28e-12 4.00e-11  1.03e-04     0s
#    9   1.12113870e+07  1.12113870e+07  0.00e+00 3.55e-11  1.03e-07     0s
#
# Barrier performed 9 iterations in 0.32 seconds (0.29 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1191    1.1211387e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 1191 iterations and 0.36 seconds (0.44 work units)
# Optimal objective  1.121138700e+07
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_scheduling.pdf
# Saved cbm_output_3 and cbm_output_4 as pickle files.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_age_distribution.pdf
#
# Old Growth Data (in hectares).
# Negative value indicates loss of old growth and positive value indicates gain of old growth.
#                   0            10    Difference
# Aspen    945.313688  13286.984131  12341.670443
# Pine     602.782616   7180.986413   6578.203796
# Bal     4315.588546  47892.760325  43577.171778
# Spruce  1072.814408  32040.931920  30968.117513
#
# Overall diversity has **increased** by 93465.16 hectares from time period 0 to time period 10.
# Clustered column plot saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_old_growth_comparison.pdf
#
# Portion for time period 0:
# Aspen: 0.2198
# Pine: 0.0581
# Bal: 0.4123
# Spruce: 0.3099
#
# Portion for time period 10:
# Aspen: 0.0720
# Pine: 0.0596
# Bal: 0.4274
# Spruce: 0.4410
#
# Shannon Evennes Index for time period 0: 0.8848
# Shannon Evennes Index for time period 10: 0.7804
#
# Diversity has **decreased** by 10.45% from time 0 to time 10.
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_bau_redchrs_species_pie.pdf
# Net emission difference -4228501.915764793
# Net emission base scenario -15207418.058538698
# Net emission alternative scenario -10978916.142773904
# dollar_per_ton is:  2.3649037411376788
# Comparison of Old Growth Areas (Alternative - Base)
#           0            10    Difference
# Aspen   0.0  20870.765041  20870.765041
# Pine    0.0   2208.999860   2208.999860
# Bal     0.0   6194.343350   6194.343350
# Spruce  0.0   9503.399757   9503.399757
#
# Overall, the old growth area has **increased** by 38777.51 hectares in the alternative scenario compared to the base scenario.
# Plot saved to ./outputs/fig/redchris/redchris_max_hv_kpi_age_difference.pdf
# Pie Charts for Time Periods 0 and 10 saved to ./outputs/fig/redchris/redchris_max_hv_kpi_species_difference_pie.pdf
# It took 61.3 minutes to run all scenarios.

# %%
print('It took', round((time.time() - Start) / 60, 1), "minutes to run this script.")
# Out:
# It took 61.3 minutes to run this script.
