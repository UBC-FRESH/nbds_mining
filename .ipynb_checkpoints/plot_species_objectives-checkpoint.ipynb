# %%
import matplotlib.pyplot as plt
import os

# Data for the two time periods
labels = ['Hem', 'DougFir', 'Aspen', 'Pine', 'Spruce', 'Bal']
sizes_period_0 = [16.6, 0.9, 1.2, 24.5, 6.6, 50.2]
sizes_max_hv = [8.2, 0.5, 1.1, 53.1, 4.2, 32.9]
sizes_min_ha = [7.8, 0.9, 1.1, 41.8, 6.3, 42.1]
sizes_maax_st = [12.1, 0.9, 1.1, 21, 11.2, 53.7]
sizes_min_ha = [8.3, 0.8, 0.9, 51.2, 4.3, 34.5]

colors = ['skyblue', 'cyan', 'red', 'purple', 'magenta', 'orange']

# Directory to save the SVG file
output_dir = './plots/fig'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, 'species_distribution.svg')

# Create the figure and axes
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot for Time Period 0
axs[0].pie(sizes_period_0, labels=labels, autopct='%1.1f%%', colors=colors)
axs[0].set_title('Species Distribution at Time Period 0')

# Plot for Time Period 10
axs[1].pie(sizes_period_10, labels=labels, autopct='%1.1f%%', colors=colors)
axs[1].set_title('Species Distribution at Time Period 10')

# Add a legend
fig.legend(labels, title="Species Present", loc='center right')

# Adjust layout
plt.tight_layout()

# Save the figure as SVG
plt.savefig(output_file, format='svg')
plt.show()

print(f"Figure saved as SVG at: {output_file}")
# Out:
# Figure saved as SVG at: ./plots/fig/species_distribution.svg
