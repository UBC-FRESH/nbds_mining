# %% [markdown]
# # Connect Forest Management Model with Forest Carbon Budget Model (without calibration)

# %% [markdown]
# ## Set up Modelling Environment

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import ws3.forest
import time
import gurobipy as grb
import pickle
import os
from util_opt import compile_scenario_maxstock, plot_scenario_maxstock, run_cbm_emissionstock, cbm_report, plugin_c_curves, compare_ws3_cbm, compile_events, plugin_c_curves_both, cbm_report_both, compare_ws3_cbm_both

# %%
def select_case_study(case_study):
    print(f"Selected scenario: {case_study}")
case_study_dropdown = widgets.Dropdown(
    options=['redchris', 'goldenbear', 'equitysilver', 'test'],
    value='redchris',
    description='Case Study:'
)
display(case_study_dropdown)
case_study_dropdown.observe(lambda change: select_case_study(change['new']), names='value')
# Out:
# Dropdown(description='Case Study:', options=('redchris', 'goldenbear', 'equitysilver', 'test'), value='redchri…

# %%
case_study = case_study_dropdown.value

# %%
#Start Calculating the Running Time
Start = time.time()

# %%
base_year = 2020
horizon = 10
period_length = 10
max_age = 1000
n_steps = 100
tvy_name = 'totvol'

# %%
# Define case study mappings
case_study_options = {
    'redchris': {
        'model_name': 'redchris',
        'model_path': './data/woodstock_model_files_redchris'
    },
    'goldenbear': {
        'model_name': 'goldenbear',
        'model_path': './data/woodstock_model_files_goldenbear'
    },
    'equitysilver': {
        'model_name': 'equitysilver',
        'model_path': './data/woodstock_model_files_equitysilver'
    },
    'test': {
        'model_name': 'redchris',
        'model_path': './data/woodstock_model_files_redchris_test'
    }
}

# Retrieve model details based on case study
model_info = case_study_options.get(case_study)

if model_info:
    model_name = model_info['model_name']
    model_path = model_info['model_path']
else:
    print('The case study name is not valid')

# %% [markdown]
# ## Create and Run `ForestModel` instance

# %%
fm = ws3.forest.ForestModel(model_name=model_name,
                            model_path=model_path,
                            base_year=base_year,
                            horizon=horizon,
                            period_length=period_length,
                            max_age=max_age)
fm.import_landscape_section()
fm.import_areas_section()
fm.import_yields_section()
fm.import_actions_section()
fm.import_transitions_section()
fm.initialize_areas()
fm.add_null_action()
fm.reset_actions()
fm.grow()

# %%
# Check the Forest Inventory of the Forest Model
df = compile_scenario_maxstock(fm)
plot_scenario_maxstock(df)
# Out:
# (<Figure size 2000x500 with 4 Axes>,
#  array([<Axes: title={'center': 'Harvested area'}, xlabel='Period', ylabel='Area (ha)'>,
#         <Axes: title={'center': 'Harvested volume'}, xlabel='Period', ylabel='Volume (m3)'>,
#         <Axes: title={'center': 'Growing Stock'}, xlabel='Period', ylabel='Volume (m3)'>,
#         <Axes: title={'center': 'Ecosystem C stock'}, xlabel='Period', ylabel='Stock (ton)'>],
#        dtype=object))

# %% [markdown]
# ## Hard-link `ForestModel` to `libcbm`

# %% [markdown]
# Prepare CBM input files

# %%
# Define Disturance Types
disturbance_type_mapping = [{'user_dist_type': 'harvest', 'default_dist_type': 'Clearcut harvesting without salvage'},
                            {'user_dist_type': 'fire', 'default_dist_type': 'Wildfire'}]
for dtype_key in fm.dtypes:
    fm.dt(dtype_key).last_pass_disturbance = 'fire' if dtype_key[5] == dtype_key[4] else 'harvest'

# %% [markdown]
# Here are other two ways to generate sit tables. But they are only suitbale for small forest model since they take too much running time and memory

# %%
sit_config, sit_tables = fm.to_cbm_sit(softwood_volume_yname='swdvol', 
                                       hardwood_volume_yname='hwdvol', 
                                       admin_boundary='British Columbia', 
                                       eco_boundary='Montane Cordillera',
                        disturbance_type_mapping=disturbance_type_mapping)

# %%
from libcbm.input.sit import sit_reader
from libcbm.input.sit import sit_cbm_factory 
from libcbm.model.cbm.cbm_output import CBMOutput
from libcbm.storage.backends import BackendType
from libcbm.model.cbm import cbm_simulator
sit_data = sit_reader.parse(sit_classifiers=sit_tables['sit_classifiers'],
                            sit_disturbance_types=sit_tables['sit_disturbance_types'],
                            sit_age_classes=sit_tables['sit_age_classes'],
                            sit_inventory=sit_tables['sit_inventory'],
                            sit_yield=sit_tables['sit_yield'],
                            sit_events=sit_tables['sit_events'],
                            sit_transitions=sit_tables['sit_transitions'],
                            sit_eligibilities=None)
sit = sit_cbm_factory.initialize_sit(sit_data=sit_data, config=sit_config)
classifiers, inventory = sit_cbm_factory.initialize_inventory(sit)
cbm_output = CBMOutput(classifier_map=sit.classifier_value_names,
                       disturbance_type_map=sit.disturbance_name_map)
with sit_cbm_factory.initialize_cbm(sit) as cbm:
    # Create a function to apply rule based disturbance events and transition rules based on the SIT input
    rule_based_processor = sit_cbm_factory.create_sit_rule_based_processor(sit, cbm)
    # The following line of code spins up the CBM inventory and runs it through 200 timesteps.
    cbm_simulator.simulate(cbm,
                           n_steps=n_steps,
                           classifiers=classifiers,
                           inventory=inventory,
                           pre_dynamics_func=rule_based_processor.pre_dynamics_func,
                           reporting_func=cbm_output.append_simulation_result,
                           backend_type=BackendType.numpy)
pi = cbm_output.classifiers.to_pandas().merge(cbm_output.pools.to_pandas(), 
                                              left_on=["identifier", "timestep"], 
                                              right_on=["identifier", "timestep"])
biomass_pools = ['SoftwoodMerch','SoftwoodFoliage', 'SoftwoodOther', 'SoftwoodCoarseRoots','SoftwoodFineRoots',                        
                 'HardwoodMerch', 'HardwoodFoliage', 'HardwoodOther', 'HardwoodCoarseRoots', 'HardwoodFineRoots']
dom_pools = ['AboveGroundVeryFastSoil', 'BelowGroundVeryFastSoil', 'AboveGroundFastSoil', 'BelowGroundFastSoil',
             'MediumSoil', 'AboveGroundSlowSoil', 'BelowGroundSlowSoil', 'SoftwoodStemSnag', 'SoftwoodBranchSnag',
             'HardwoodStemSnag', 'HardwoodBranchSnag']

# %%
emissions_pools = ['CO2', 'CH4', 'CO', 'NO2']
ecosystem_pools = biomass_pools + dom_pools

# %%
# Define Time Steps
n_steps = fm.horizon * fm.period_length

# Run CBM and Generate CBM 0utputs
cbm_output = run_cbm_emissionstock(sit_config, sit_tables, n_steps)

# %% [markdown]
# Emissions from all biomass components only resulting from fire disturbance, while these from all DOM pools resulting from annual decay processes and fire disturbance.

# %%
# Define Carbon Fluxes
all_fluxes = [
    'DisturbanceCO2Production',
    'DisturbanceCH4Production',
    'DisturbanceCOProduction',
    'DisturbanceBioCO2Emission',
    'DisturbanceBioCH4Emission',
    'DisturbanceBioCOEmission',
    'DecayDOMCO2Emission',
    'DisturbanceSoftProduction',
    'DisturbanceHardProduction',
    'DisturbanceDOMProduction',
    'DeltaBiomass_AG',
    'DeltaBiomass_BG',
    'TurnoverMerchLitterInput',
    'TurnoverFolLitterInput',
    'TurnoverOthLitterInput',
    'TurnoverCoarseLitterInput',
    'TurnoverFineLitterInput',
    'DecayVFastAGToAir',
    'DecayVFastBGToAir',
    'DecayFastAGToAir',
    'DecayFastBGToAir',
    'DecayMediumToAir',
    'DecaySlowAGToAir',
    'DecaySlowBGToAir',
    'DecaySWStemSnagToAir',
    'DecaySWBranchSnagToAir',
    'DecayHWStemSnagToAir',
    'DecayHWBranchSnagToAir',
    'DisturbanceMerchToAir',
    'DisturbanceFolToAir',
    'DisturbanceOthToAir',
    'DisturbanceCoarseToAir',
    'DisturbanceFineToAir',
    'DisturbanceDOMCO2Emission',
    'DisturbanceDOMCH4Emission',
    'DisturbanceDOMCOEmission',
    'DisturbanceMerchLitterInput',
    'DisturbanceFolLitterInput',
    'DisturbanceOthLitterInput',
    'DisturbanceCoarseLitterInput',
    'DisturbanceFineLitterInput',
    'DisturbanceVFastAGToAir',
    'DisturbanceVFastBGToAir',
    'DisturbanceFastAGToAir',
    'DisturbanceFastBGToAir',
    'DisturbanceMediumToAir',
    'DisturbanceSlowAGToAir',
    'DisturbanceSlowBGToAir',
    'DisturbanceSWStemSnagToAir',
    'DisturbanceSWBranchSnagToAir',
    'DisturbanceHWStemSnagToAir',
    'DisturbanceHWBranchSnagToAir'
]

ecosystem_decay_emissions_pools = [
    'DecayVFastAGToAir',
    'DecayVFastBGToAir',
    'DecayFastAGToAir',
    'DecayFastBGToAir',
    'DecayMediumToAir',
    'DecaySlowAGToAir',
    'DecaySlowBGToAir',
    'DecaySWStemSnagToAir',
    'DecaySWBranchSnagToAir',
    'DecayHWStemSnagToAir',
    'DecayHWBranchSnagToAir']
GrossGrowth_pools = [
    'DeltaBiomass_AG',
    'TurnoverMerchLitterInput',
    'TurnoverFolLitterInput',
    'TurnoverOthLitterInput',
    'DeltaBiomass_BG',
    'TurnoverCoarseLitterInput',
    'TurnoverFineLitterInput']

# %%
# Define Sum Carbon Pools and Sum Carbon Fluxes
pools = ecosystem_pools
fluxes = ecosystem_decay_emissions_pools
gross_growth = GrossGrowth_pools
sum_pools = ['ecosystem', 'biomass', 'DOM']

# %%
# Report Annual CBM Results
cbm_report(fm, cbm_output, biomass_pools, dom_pools, fluxes, gross_growth)
# Out:
#            Biomass           DOM     Ecosystem  All_Emissions   Gross_Growth  \
# Year
# 0     7.144077e+06  1.998170e+07  2.712578e+07       0.000000       0.000000
# 1     7.276708e+06  1.998549e+07  2.726219e+07  435162.492686  571575.647093
# 2     7.409069e+06  1.999109e+07  2.740015e+07  438131.530633  576091.686330
# 3     7.540872e+06  1.999840e+07  2.753928e+07  441090.837166  580213.676778
# 4     7.672226e+06  2.000734e+07  2.767957e+07  444034.437628  584327.359615
# ...            ...           ...           ...            ...            ...
# 96    1.649951e+07  2.372710e+07  4.022661e+07  608901.203780  706817.788031
# 97    1.654539e+07  2.377783e+07  4.032322e+07  609874.538109  706489.331653
# 98    1.659022e+07  2.382849e+07  4.041871e+07  610834.121239  706318.529561
# 99    1.663388e+07  2.387906e+07  4.051294e+07  611780.073467  706009.121833
# 100   1.667641e+07  2.392955e+07  4.060596e+07  612712.435080  705733.531906
#
#        Stock_Change
# Year
# 0          0.000000
# 1    -136413.154407
# 2    -137960.155697
# 3    -139122.839612
# 4    -140292.921987
# ...             ...
# 96    -97916.584251
# 97    -96614.793544
# 98    -95484.408321
# 99    -94229.048366
# 100   -93021.096826
#
# [101 rows x 6 columns]

# %% [markdown]
# ## Generate and Add Carbon Yield Curves

# %% [markdown]
# Carbon in product pools is considered a 100% immediate emission after harvesting activities.

# %% [markdown]
# Rebuild the inventory table. Set age to 0 and area to 1.0 ha.

# %% [markdown]
# The `sit_events` table should be empty.

# %%
sit_tables['sit_events']
# Out:
# Empty DataFrame
# Columns: [theme0, theme1, theme2, theme3, theme4, theme5, species, using_age_class, min_softwood_age, max_softwood_age, min_hardwood_age, max_hardwood_age, MinYearsSinceDist, MaxYearsSinceDist, LastDistTypeID, MinTotBiomassC, MaxTotBiomassC, MinSWMerchBiomassC, MaxSWMerchBiomassC, MinHWMerchBiomassC, MaxHWMerchBiomassC, MinTotalStemSnagC, MaxTotalStemSnagC, MinSWStemSnagC, MaxSWStemSnagC, MinHWStemSnagC, MaxHWStemSnagC, MinTotalStemSnagMerchC, MaxTotalStemSnagMerchC, MinSWMerchStemSnagC, MaxSWMerchStemSnagC, MinHWMerchStemSnagC, MaxHWMerchStemSnagC, efficiency, sort_type, target_type, target, disturbance_type, disturbance_year]
# Index: []
#
# [0 rows x 39 columns]

# %%
sit_tables['sit_inventory']
# Out:
#      theme0 theme1 theme2 theme3 theme4 theme5   species using_age_class  age  \
# 0     tsa04      0      1    100     12     12  softwood           FALSE   20
# 1     tsa04      0      1    100     12     12  softwood           FALSE   21
# 2     tsa04      0      1    100     12     12  softwood           FALSE   26
# 3     tsa04      0      1    100     30     30  softwood           FALSE   23
# 4     tsa04      0      1    100     30     30  softwood           FALSE   24
# ...     ...    ...    ...    ...    ...    ...       ...             ...  ...
# 3900  tsa04      1     33   1201     42     42  hardwood           FALSE   88
# 3901  tsa04      1     33   1201     42     42  hardwood           FALSE   94
# 3902  tsa04      1     33   1201     42     42  hardwood           FALSE  109
# 3903  tsa04      1     33   1201     42     42  hardwood           FALSE  116
# 3904  tsa04      1     33   1201     42     42  hardwood           FALSE  139
#
#             area  delay landclass historic_disturbance last_pass_disturbance
# 0       3.238770      0         0                 fire                  fire
# 1       2.524772      0         0                 fire                  fire
# 2       3.917482      0         0                 fire                  fire
# 3      10.346732      0         0                 fire                  fire
# 4       8.210417      0         0                 fire                  fire
# ...          ...    ...       ...                  ...                   ...
# 3900   33.639536      0         0                 fire                  fire
# 3901   32.511218      0         0                 fire                  fire
# 3902  133.464928      0         0                 fire                  fire
# 3903   14.516802      0         0                 fire                  fire
# 3904   23.959049      0         0                 fire                  fire
#
# [3905 rows x 14 columns]

# %%
# Set Age and Area to 1 and 1.0
df = sit_tables['sit_inventory']
df['age'] = df['age'].apply(lambda x: 0)
df['area'] = df['area'].apply(lambda x: 1.0)
df = df.drop_duplicates(ignore_index=True)
df
# Out:
#     theme0 theme1 theme2 theme3 theme4 theme5   species using_age_class  age  \
# 0    tsa04      0      1    100     12     12  softwood           FALSE    0
# 1    tsa04      0      1    100     30     30  softwood           FALSE    0
# 2    tsa04      0      2    100     10     10  softwood           FALSE    0
# 3    tsa04      0      2    100     12     12  softwood           FALSE    0
# 4    tsa04      0      2    100     28     28  softwood           FALSE    0
# ..     ...    ...    ...    ...    ...    ...       ...             ...  ...
# 253  tsa04      1     33   1201     32     32  hardwood           FALSE    0
# 254  tsa04      1     33   1201     33     33  hardwood           FALSE    0
# 255  tsa04      1     33   1201     40     40  hardwood           FALSE    0
# 256  tsa04      1     33   1201     41     41  hardwood           FALSE    0
# 257  tsa04      1     33   1201     42     42  hardwood           FALSE    0
#
#      area  delay landclass historic_disturbance last_pass_disturbance
# 0     1.0      0         0                 fire                  fire
# 1     1.0      0         0                 fire                  fire
# 2     1.0      0         0                 fire                  fire
# 3     1.0      0         0                 fire                  fire
# 4     1.0      0         0                 fire                  fire
# ..    ...    ...       ...                  ...                   ...
# 253   1.0      0         0                 fire                  fire
# 254   1.0      0         0                 fire                  fire
# 255   1.0      0         0                 fire                  fire
# 256   1.0      0         0                 fire                  fire
# 257   1.0      0         0                 fire                  fire
#
# [258 rows x 14 columns]

# %% [markdown]
# Use the following code if any of the developments have no harvesting circumstances.

# %%
# # Replace the Sit Inventory File in the Sit Table
sit_tables['sit_inventory'] = df

# %%
# Run CBM and Generate CBM 0utputs
cbm_output = run_cbm_emissionstock(sit_config, sit_tables, n_steps)

# %%
# Generate Carbon Pool and Flux Indicators
pi = cbm_output.classifiers.to_pandas().merge(cbm_output.pools.to_pandas(), 
                                              left_on=["identifier", "timestep"], 
                                              right_on=["identifier", "timestep"])
fi = cbm_output.classifiers.to_pandas().merge(cbm_output.flux.to_pandas(), 
                                              left_on=["identifier", "timestep"], 
                                              right_on=["identifier", "timestep"])

# %%
# Define Development Type Keys
pi['dtype_key'] = pi.apply(lambda r: '%s %s %s %s %s %s' % (r['theme0'], r['theme1'], r['theme2'], r['theme3'], r['theme4'], r['theme5']), axis=1)
fi['dtype_key'] = fi.apply(lambda r: '%s %s %s %s %s %s' % (r['theme0'], r['theme1'], r['theme2'], r['theme3'], r['theme4'], r['theme5']), axis=1)

# %%
# Generate Carbon Pool anf Flux Curves
c_curves_p = pi.groupby(['dtype_key', 'timestep'], as_index=True)[ecosystem_pools].sum()
c_curves_f = fi.groupby(['dtype_key', 'timestep'], as_index=True)[all_fluxes].sum()

# %%
# Generate sum carbon pool curves
c_curves_p['ecosystem'] = c_curves_p[ecosystem_pools].sum(axis=1)
c_curves_p['biomass'] = c_curves_p[biomass_pools].sum(axis=1)
c_curves_p['DOM'] = c_curves_p[dom_pools].sum(axis=1)

# %%
c_curves_f['total_emissions'] = 44/12 * c_curves_f[fluxes].sum(axis=1)
c_curves_f['gross_growth'] = 44/12 * c_curves_f[gross_growth].sum(axis=1)
c_curves_f['net_emissions'] = c_curves_f['total_emissions'] - c_curves_f['gross_growth']

# %%
# Curvs Calibration
# c_curves_p = c_curves_p.iloc[:,-3:].apply(lambda x: x*1.03) # Calibrate the carbon yield curvest for total ecosystem pools
# c_curves_f = c_curves_f.iloc[:,-2:].apply(lambda x: x*1.03) # Calibrate the carbon yield curvest for net carbon flux

# %%
# Use pickle.dump, to store the curves
file_directory = "./inputs/curves"
os.makedirs(file_directory, exist_ok=True)

file_data = {
    f"{case_study}_c_curves_p.pkl": c_curves_p,
    f"{case_study}_c_curves_f.pkl": c_curves_f
}

for filename, data in file_data.items():
    file_path = os.path.join(file_directory, filename)
    with open(file_path, 'wb') as file:
        pickle.dump(data, file)
    print(f"File saved at {file_path}")
# Out:
# File saved at ./inputs/curves/goldenbear_c_curves_p.pkl
# File saved at ./inputs/curves/goldenbear_c_curves_f.pkl

# %%
# with open(f'{case_study}_c_curves_p_test.pkl', 'rb') as file:
#     c_curves_p = pickle.load(file)

# %%
# with open(f'{case_study}_c_curves_f_test.pkl', 'rb') as file:
#     c_curves_f = pickle.load(file)

# %%
# Plug carbon yield curves into forest model
plugin_c_curves_both(fm, c_curves_p, c_curves_f)
# plugin_c_curves(fm, c_curves_p, pools=sum_pools) # This is only for c_curves_p
# Out:
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '10', '10')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '28', '28')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '10', '10')
# found match for mask ('?', '?', '?', '?', '11', '11')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '28', '28')
# found match for mask ('?', '?', '?', '?', '29', '29')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '38', '38')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '8', '8')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '38', '38')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '8', '8')
# found match for mask ('?', '?', '?', '?', '28', '28')
# found match for mask ('?', '?', '?', '?', '29', '29')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '22', '22')
# found match for mask ('?', '?', '?', '?', '23', '23')
# found match for mask ('?', '?', '?', '?', '24', '24')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '26', '26')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '31', '31')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '5', '5')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '5', '5')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '1', '1')
# found match for mask ('?', '?', '?', '?', '2', '2')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '26', '26')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '34', '34')
# found match for mask ('?', '?', '?', '?', '35', '35')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '16', '16')
# found match for mask ('?', '?', '?', '?', '18', '18')
# found match for mask ('?', '?', '?', '?', '16', '16')
# found match for mask ('?', '?', '?', '?', '17', '17')
# found match for mask ('?', '?', '?', '?', '18', '18')
# found match for mask ('?', '?', '?', '?', '16', '16')
# found match for mask ('?', '?', '?', '?', '17', '17')
# found match for mask ('?', '?', '?', '?', '34', '34')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '1', '1')
# found match for mask ('?', '?', '?', '?', '2', '2')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '31', '31')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '8', '8')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '38', '38')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '16', '16')
# found match for mask ('?', '?', '?', '?', '17', '17')
# found match for mask ('?', '?', '?', '?', '18', '18')
# found match for mask ('?', '?', '?', '?', '19', '19')
# found match for mask ('?', '?', '?', '?', '20', '20')
# found match for mask ('?', '?', '?', '?', '21', '21')
# found match for mask ('?', '?', '?', '?', '40', '40')
# found match for mask ('?', '?', '?', '?', '41', '41')
# found match for mask ('?', '?', '?', '?', '42', '42')
# found match for mask ('?', '?', '?', '?', '10', '10')
# found match for mask ('?', '?', '?', '?', '11', '11')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '29', '29')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '22', '22')
# found match for mask ('?', '?', '?', '?', '23', '23')
# found match for mask ('?', '?', '?', '?', '24', '24')
# found match for mask ('?', '?', '?', '?', '1', '1')
# found match for mask ('?', '?', '?', '?', '2', '2')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '34', '34')
# found match for mask ('?', '?', '?', '?', '35', '35')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '19', '19')
# found match for mask ('?', '?', '?', '?', '20', '20')
# found match for mask ('?', '?', '?', '?', '21', '21')
# found match for mask ('?', '?', '?', '?', '31', '31')
# found match for mask ('?', '?', '?', '?', '32', '32')
# found match for mask ('?', '?', '?', '?', '33', '33')
# found match for mask ('?', '?', '?', '?', '40', '40')
# found match for mask ('?', '?', '?', '?', '41', '41')
# found match for mask ('?', '?', '?', '?', '42', '42')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '10', '10')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '28', '28')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '10', '10')
# found match for mask ('?', '?', '?', '?', '11', '11')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '29', '29')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '38', '38')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '8', '8')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '38', '38')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '8', '8')
# found match for mask ('?', '?', '?', '?', '29', '29')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '22', '22')
# found match for mask ('?', '?', '?', '?', '23', '23')
# found match for mask ('?', '?', '?', '?', '24', '24')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '26', '26')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '31', '31')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '5', '5')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '5', '5')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '1', '1')
# found match for mask ('?', '?', '?', '?', '2', '2')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '26', '26')
# found match for mask ('?', '?', '?', '?', '27', '27')
# found match for mask ('?', '?', '?', '?', '34', '34')
# found match for mask ('?', '?', '?', '?', '35', '35')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '16', '16')
# found match for mask ('?', '?', '?', '?', '18', '18')
# found match for mask ('?', '?', '?', '?', '17', '17')
# found match for mask ('?', '?', '?', '?', '18', '18')
# found match for mask ('?', '?', '?', '?', '17', '17')
# found match for mask ('?', '?', '?', '?', '34', '34')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '1', '1')
# found match for mask ('?', '?', '?', '?', '2', '2')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '25', '25')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '31', '31')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '7', '7')
# found match for mask ('?', '?', '?', '?', '8', '8')
# found match for mask ('?', '?', '?', '?', '9', '9')
# found match for mask ('?', '?', '?', '?', '37', '37')
# found match for mask ('?', '?', '?', '?', '38', '38')
# found match for mask ('?', '?', '?', '?', '39', '39')
# found match for mask ('?', '?', '?', '?', '4', '4')
# found match for mask ('?', '?', '?', '?', '5', '5')
# found match for mask ('?', '?', '?', '?', '6', '6')
# found match for mask ('?', '?', '?', '?', '17', '17')
# found match for mask ('?', '?', '?', '?', '18', '18')
# found match for mask ('?', '?', '?', '?', '19', '19')
# found match for mask ('?', '?', '?', '?', '20', '20')
# found match for mask ('?', '?', '?', '?', '21', '21')
# found match for mask ('?', '?', '?', '?', '40', '40')
# found match for mask ('?', '?', '?', '?', '41', '41')
# found match for mask ('?', '?', '?', '?', '42', '42')
# found match for mask ('?', '?', '?', '?', '10', '10')
# found match for mask ('?', '?', '?', '?', '11', '11')
# found match for mask ('?', '?', '?', '?', '12', '12')
# found match for mask ('?', '?', '?', '?', '29', '29')
# found match for mask ('?', '?', '?', '?', '30', '30')
# found match for mask ('?', '?', '?', '?', '22', '22')
# found match for mask ('?', '?', '?', '?', '23', '23')
# found match for mask ('?', '?', '?', '?', '24', '24')
# found match for mask ('?', '?', '?', '?', '1', '1')
# found match for mask ('?', '?', '?', '?', '2', '2')
# found match for mask ('?', '?', '?', '?', '3', '3')
# found match for mask ('?', '?', '?', '?', '34', '34')
# found match for mask ('?', '?', '?', '?', '35', '35')
# found match for mask ('?', '?', '?', '?', '36', '36')
# found match for mask ('?', '?', '?', '?', '13', '13')
# found match for mask ('?', '?', '?', '?', '14', '14')
# found match for mask ('?', '?', '?', '?', '15', '15')
# found match for mask ('?', '?', '?', '?', '19', '19')
# found match for mask ('?', '?', '?', '?', '20', '20')
# found match for mask ('?', '?', '?', '?', '21', '21')
# found match for mask ('?', '?', '?', '?', '31', '31')
# found match for mask ('?', '?', '?', '?', '32', '32')
# found match for mask ('?', '?', '?', '?', '33', '33')
# found match for mask ('?', '?', '?', '?', '40', '40')
# found match for mask ('?', '?', '?', '?', '41', '41')
# found match for mask ('?', '?', '?', '?', '42', '42')

# %%
# Check if all carbon yield curves are plugged in well.
fm.yields
# Out:
# [(('?', '?', '?', '?', '?', '?'), '', []),
#  (('?', '?', '?', '?', '7', '7'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda040f21a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1f30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3490>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3a60>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3d30>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3d00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3460>)]),
#  (('?', '?', '?', '?', '16', '16'),
#   'a',
#   [('s0304', <ws3.core.Curve at 0x7fda040f22c0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8b20>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db8e80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8a90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db87c0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8fd0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db94e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8b20>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db8e80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8a90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db87c0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8fd0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db94e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8b20>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db8e80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8a90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db87c0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8fd0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db94e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8b20>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db8e80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8a90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db87c0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8fd0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db94e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8b20>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db8e80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8a90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db87c0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8fd0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db94e0>)]),
#  (('?', '?', '?', '?', '5', '5'),
#   'a',
#   [('s0204', <ws3.core.Curve at 0x7fda040f0eb0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9ba0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbaa10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9780>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93641f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbbbe0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9e40>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9ba0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbaa10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9780>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93641f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbbbe0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9e40>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9ba0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbaa10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9780>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93641f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbbbe0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9e40>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9ba0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbaa10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9780>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93641f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbbbe0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9e40>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9ba0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbaa10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9780>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93641f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbbbe0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9e40>)]),
#  (('?', '?', '?', '?', '4', '4'),
#   'a',
#   [('s0204', <ws3.core.Curve at 0x7fda040f2410>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba050>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbaf20>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8a60>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb3a0>)]),
#  (('?', '?', '?', '?', '17', '17'),
#   'a',
#   [('s0304', <ws3.core.Curve at 0x7fda040f2830>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8ee0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db87f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb400>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8130>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbba90>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9514880>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8ee0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db87f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb400>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8130>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbba90>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9514880>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8ee0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db87f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb400>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8130>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbba90>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9514880>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8ee0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db87f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb400>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8130>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbba90>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9514880>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8ee0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db87f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb400>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8130>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbba90>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9514880>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8ee0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db87f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb400>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8130>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbba90>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9514880>)]),
#  (('?', '?', '?', '?', '20', '20'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda040f2320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2bf0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408640>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409ff0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f2f50>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8409e40>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840a320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2bf0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408640>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409ff0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f2f50>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8409e40>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840a320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2bf0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408640>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409ff0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f2f50>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8409e40>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840a320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2bf0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408640>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409ff0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f2f50>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8409e40>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840a320>)]),
#  (('?', '?', '?', '?', '40', '40'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda040f2380>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8408ca0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408040>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840ba90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f32e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840ba00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409420>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8408ca0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408040>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840ba90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f32e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840ba00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409420>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8408ca0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408040>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840ba90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f32e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840ba00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409420>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8408ca0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408040>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840ba90>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f32e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840ba00>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409420>)]),
#  (('?', '?', '?', '?', '21', '21'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda040f1930>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f2b00>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84081c0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8408130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f29b0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b220>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409690>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f2b00>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84081c0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8408130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f29b0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b220>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409690>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f2b00>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84081c0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8408130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f29b0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b220>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409690>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f2b00>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84081c0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8408130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fda040f29b0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b220>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8409690>)]),
#  (('?', '?', '?', '?', '3', '3'),
#   'a',
#   [('s0304', <ws3.core.Curve at 0x7fda040f2140>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8dba4a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb460>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb9a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba800>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9960>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbb280>)]),
#  (('?', '?', '?', '?', '19', '19'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda040f1630>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cccd0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84098d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840a1a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f928acb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b730>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ae00>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cccd0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84098d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840a1a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f928acb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b730>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ae00>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cccd0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84098d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840a1a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f928acb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b730>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ae00>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cccd0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84098d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840a1a0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f928acb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840b730>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ae00>)]),
#  (('?', '?', '?', '?', '22', '22'),
#   'a',
#   [('s0204', <ws3.core.Curve at 0x7fda040f1b70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d38b0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2c80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2fb0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d23e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d31f0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3010>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d38b0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2c80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2fb0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d23e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d31f0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3010>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d38b0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2c80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2fb0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d23e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d31f0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3010>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d38b0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2c80>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2fb0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d23e0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d31f0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3010>)]),
#  (('?', '?', '?', '?', '8', '8'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda040f1240>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d30a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3310>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d36a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d32b0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3370>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d30a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3310>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d36a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d32b0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3370>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d30a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3310>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d36a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d32b0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3370>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d30a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3310>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d36a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d32b0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3370>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d30a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3310>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d36a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d32b0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3370>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d30a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3310>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d3130>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d36a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d32b0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3370>)]),
#  (('?', '?', '?', '?', '18', '18'),
#   'a',
#   [('s0304', <ws3.core.Curve at 0x7fda040f11b0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8250>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbad10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8cd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8280>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8ac0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8d30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8250>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbad10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8cd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8280>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8ac0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8d30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8250>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbad10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8cd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8280>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8ac0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8d30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8250>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbad10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8cd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8280>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8ac0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8d30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8250>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbad10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8cd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8280>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8ac0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8d30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8250>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbad10>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db8cd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8280>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8ac0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8d30>)]),
#  (('?', '?', '?', '?', '6', '6'),
#   'a',
#   [('s0204', <ws3.core.Curve at 0x7fda040f14b0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2800>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db96f0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d2350>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb070>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db9fc0>)]),
#  (('?', '?', '?', '?', '9', '9'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda040f1210>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d3a30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d3b50>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0be0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3eb0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d3880>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d3c70>)]),
#  (('?', '?', '?', '?', '14', '14'),
#   'a',
#   [('s0403', <ws3.core.Curve at 0x7fda040f1a80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f3010>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb790>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409210>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d3fa0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fda040f3ee0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f840ac80>)]),
#  (('?', '?', '?', '?', '34', '34'),
#   'a',
#   [('s0304', <ws3.core.Curve at 0x7fda040f10f0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8040>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db83d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9030>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8550>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8340>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8580>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8040>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db83d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9030>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8550>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8340>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8580>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8040>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db83d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9030>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8550>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8340>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8580>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8040>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db83d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9030>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8550>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8340>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8580>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8040>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db83d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9030>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8550>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8340>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8580>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db8040>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db83d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8db9030>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8db8550>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db8340>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8db8580>)]),
#  (('?', '?', '?', '?', '15', '15'),
#   'a',
#   [('s0403', <ws3.core.Curve at 0x7fda040f10c0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfd90>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dba2f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba2c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbb3d0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d2680>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f9288190>)]),
#  (('?', '?', '?', '?', '36', '36'),
#   'a',
#   [('s0304', <ws3.core.Curve at 0x7fda040f26b0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8db9f60>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb1f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dbb250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dba080>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8dbb700>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbae30>)]),
#  (('?', '?', '?', '?', '28', '28'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda045f1ab0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93646d0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93647f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f9365720>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9367ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365e10>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93646d0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93647f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f9365720>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9367ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365e10>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93646d0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93647f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f9365720>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9367ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365e10>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2320>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93646d0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93647f0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f9365720>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9367ca0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365e10>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2320>)]),
#  (('?', '?', '?', '?', '13', '13'),
#   'a',
#   [('s0403', <ws3.core.Curve at 0x7fda043a4700>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfa30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9330>),
#    ('DOM', <ws3.core.Curve at 0x7fda040f2770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbabf0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9288040>),
#    ('gross_growth', <ws3.core.Curve at 0x7fda040f31f0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfa30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9330>),
#    ('DOM', <ws3.core.Curve at 0x7fda040f2770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbabf0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9288040>),
#    ('gross_growth', <ws3.core.Curve at 0x7fda040f31f0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfa30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9330>),
#    ('DOM', <ws3.core.Curve at 0x7fda040f2770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbabf0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9288040>),
#    ('gross_growth', <ws3.core.Curve at 0x7fda040f31f0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfa30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9330>),
#    ('DOM', <ws3.core.Curve at 0x7fda040f2770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbabf0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9288040>),
#    ('gross_growth', <ws3.core.Curve at 0x7fda040f31f0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfa30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9330>),
#    ('DOM', <ws3.core.Curve at 0x7fda040f2770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbabf0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9288040>),
#    ('gross_growth', <ws3.core.Curve at 0x7fda040f31f0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda018cfa30>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8db9330>),
#    ('DOM', <ws3.core.Curve at 0x7fda040f2770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8dbabf0>),
# ...
#    ('DOM', <ws3.core.Curve at 0x7fd9f93650c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365600>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365fc0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93678e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366830>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f9367010>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93650c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365600>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365fc0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93678e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366830>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f9367010>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93650c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365600>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365fc0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93678e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366830>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f9367010>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93650c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365600>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365fc0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93678e0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366830>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f9367010>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93650c0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365600>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f9365fc0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93678e0>)]),
#  (('?', '?', '?', '?', '24', '24'),
#   'a',
#   [('s0204', <ws3.core.Curve at 0x7fda040b8be0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2710>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2830>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2dd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d28f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d27d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2500>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2710>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2830>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2dd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d28f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d27d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2500>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2710>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2830>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2dd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d28f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d27d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2500>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2710>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d2830>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d2dd0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d28f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d27d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d2500>)]),
#  (('?', '?', '?', '?', '41', '41'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda040b8ac0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f840a350>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84085e0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409360>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8409f60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8408af0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408400>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f840a350>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84085e0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409360>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8409f60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8408af0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408400>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f840a350>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84085e0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409360>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8409f60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8408af0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408400>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f840a350>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f84085e0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409360>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8409f60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8408af0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408400>)]),
#  (('?', '?', '?', '?', '37', '37'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda040b8910>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f9366530>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d00d0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0250>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9365e40>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1d20>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d0a90>)]),
#  (('?', '?', '?', '?', '42', '42'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda040f2500>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8409750>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408f40>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840aec0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8408e20>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840a080>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408df0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8409750>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408f40>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840aec0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8408e20>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840a080>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408df0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8409750>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408f40>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840aec0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8408e20>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840a080>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408df0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f8409750>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8408f40>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f840aec0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f8408e20>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f840a080>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8408df0>)]),
#  (('?', '?', '?', '?', '39', '39'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda0486a560>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d1780>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d0af0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d0ee0>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d1030>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d1330>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d1900>)]),
#  (('?', '?', '?', '?', '38', '38'),
#   'a',
#   [('s0100', <ws3.core.Curve at 0x7fda0486a800>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93661a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d1810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d1870>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9364d60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d18d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d09d0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93661a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d1810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d1870>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9364d60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d18d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d09d0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93661a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d1810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d1870>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9364d60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d18d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d09d0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93661a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d1810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d1870>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9364d60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d18d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d09d0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93661a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d1810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d1870>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9364d60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d18d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d09d0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93661a0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f93d1810>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f93d1870>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f9364d60>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f93d18d0>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f93d09d0>)]),
#  (('?', '?', '?', '?', '31', '31'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda0486a770>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2380>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb820>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d27a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9b70>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbba30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2380>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb820>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d27a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9b70>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbba30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2380>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb820>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d27a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9b70>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbba30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2380>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb820>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d27a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9b70>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbba30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2380>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb820>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d27a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9b70>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbba30>),
#    ('ecosystem', <ws3.core.Curve at 0x7fd9f93d2380>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8dbb820>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8dba770>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f93d27a0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8db9b70>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f8dbba30>)]),
#  (('?', '?', '?', '?', '32', '32'),
#   'a',
#   [('s1201', <ws3.core.Curve at 0x7fda0493e1a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f38e0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8409cc0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409570>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f84099f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8409a50>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f88bd8a0>),
#    ('ecosystem', <ws3.core.Curve at 0x7fda040f38e0>),
#    ('biomass', <ws3.core.Curve at 0x7fd9f8409cc0>),
#    ('DOM', <ws3.core.Curve at 0x7fd9f8409570>),
#    ('net_emissions', <ws3.core.Curve at 0x7fd9f84099f0>),
#    ('total_emissions', <ws3.core.Curve at 0x7fd9f8409a50>),
#    ('gross_growth', <ws3.core.Curve at 0x7fd9f88bd8a0>)]),
#  (('?', '?', '?', '?', '?', '?'),
#   'c',
#   [('totvol', '_SUM(s0100, s0304, s0204, s1201, s0403)'),
#    ('swdvol', '_SUM(s0100, s0304, s0204, s0403)'),
#    ('hwdvol', '_SUM(s1201)')])]

# %%
df = compile_scenario_maxstock(fm)
plot_scenario_maxstock(df)
# Out:
# (<Figure size 2000x500 with 4 Axes>,
#  array([<Axes: title={'center': 'Harvested area'}, xlabel='Period', ylabel='Area (ha)'>,
#         <Axes: title={'center': 'Harvested volume'}, xlabel='Period', ylabel='Volume (m3)'>,
#         <Axes: title={'center': 'Growing Stock'}, xlabel='Period', ylabel='Volume (m3)'>,
#         <Axes: title={'center': 'Ecosystem C stock'}, xlabel='Period', ylabel='Stock (ton)'>],
#        dtype=object))

# %%
# Run CBM and Generate CBM Ouputs
cbm_output = run_cbm_emissionstock(sit_config, sit_tables, n_steps)

# %%
# Report Annual CBM Outputs
# cbm_report(fm, cbm_output, biomass_pools, dom_pools, fluxes, gross_growth)
cbm_report_both(fm, cbm_output, biomass_pools, dom_pools, fluxes, gross_growth)
# Out:
#            Biomass           DOM     Ecosystem  All_Emissions  Gross_Growth  \
# Year
# 0         0.000000  43556.176664  43556.176664       0.000000      0.000000
# 1        30.392316  42618.070413  42648.462729    3457.252781   -128.968350
# 2        62.431270  41754.026435  41816.457706    3216.290831   -165.605747
# 3        97.735588  40950.723512  41048.459099    3018.952495   -202.957605
# 4       136.358435  40199.273831  40335.632267    2853.671575   -239.973189
# ...            ...           ...           ...            ...           ...
# 96    14925.753802  28654.758697  43580.512499    2567.361414  -3407.394954
# 97    15108.639902  28700.066589  43808.706492    2577.930167  -3414.641472
# 98    15290.899494  28746.373774  44037.273269    2588.366105  -3426.444288
# 99    15472.550274  28793.677134  44266.227408    2598.679312  -3438.177823
# 100   15653.608981  28841.972413  44495.581394    2608.878960  -3449.843574
#
#       Stock_Change  Net_Emissions
# Year
# 0         0.000000       0.000000
# 1       907.713936    3328.284431
# 2       832.005023    3050.685084
# 3       767.998606    2815.994890
# 4       712.826833    2613.698386
# ...            ...            ...
# 96     -229.100056    -840.033539
# 97     -228.193992    -836.711305
# 98     -228.566777    -838.078184
# 99     -228.954139    -839.498511
# 100    -229.353986    -840.964614
#
# [101 rows x 7 columns]

# %%
# Compare the carbon outputs from ws3 (table above) and libcbm (table below)
# compare_ws3_cbm(fm, cbm_output, disturbance_type_mapping, biomass_pools, dom_pools, plots="individual")
compare_ws3_cbm_both(fm, cbm_output, disturbance_type_mapping, biomass_pools, dom_pools, ecosystem_decay_emissions_pools, GrossGrowth_pools, plots="individual")
# Out:
# (   period  biomass_stock     dom_stock     eco_stock  \
#  0       1      30.392316  42618.070413  42648.462729
#  1       2     503.300655  35995.886384  36499.187040
#  2       3    1348.725949  32112.209161  33460.935110
#  3       4    2600.119031  29808.364435  32408.483465
#  4       5    4210.530156  28522.480203  32733.010358
#  5       6    6153.747232  27919.592408  34073.339639
#  6       7    8229.890428  27771.091759  36000.982187
#  7       8   10188.090168  27867.781917  38055.872086
#  8       9   12106.110810  28101.875719  40207.986529
#  9      10   13994.816640  28443.886396  42438.703036
#
#     ecosystem_decay_emissions  gross_growth  net_emissions  eco_stock_change
#  0                3457.252781   -128.968350    3328.284431          0.000000
#  1                2142.838722   -510.432524    1632.406197      -6149.275689
#  2                1678.325193   -935.270565     743.054627      -3038.251930
#  3                1556.228735  -1427.971231     128.257503      -1052.451644
#  4                1639.909060  -1946.903887    -306.994828        324.526893
#  5                1826.114930  -2446.449323    -620.334393       1340.329281
#  6                2043.167065  -2803.856564    -760.689499       1927.642548
#  7                2234.981462  -3036.578578    -801.597116       2054.889898
#  8                2388.674299  -3205.689243    -817.014945       2152.114443
#  9                2512.480644  -3345.927846    -833.447202       2230.716507  ,
#     period  biomass_stock     dom_stock     eco_stock  net_emissions  \
#  0       1   6.879350e+06  1.991907e+07  2.674304e+07 -496243.784343
#  1       2   8.007140e+06  1.994834e+07  2.790846e+07 -539650.583539
#  2       3   8.960413e+06  2.003515e+07  2.895609e+07 -561552.631374
#  3       4   9.702952e+06  2.012307e+07  2.979727e+07 -576574.560246
#  4       5   1.020315e+07  2.018745e+07  3.037906e+07 -583205.682600
#  5       6   1.049574e+07  2.022785e+07  3.072621e+07 -587570.521949
#  6       7   1.064915e+07  2.025056e+07  3.091032e+07 -589720.893774
#  7       8   1.072408e+07  2.026421e+07  3.100162e+07 -589543.027645
#  8       9   1.075565e+07  2.027209e+07  3.104217e+07 -588709.315489
#  9      10   1.077122e+07  2.027717e+07  3.106293e+07 -588897.852633
#
#     eco_stock_change
#  0      0.000000e+00
#  1      1.165423e+06
#  2      1.047623e+06
#  3      8.411790e+05
#  4      5.817957e+05
#  5      3.471514e+05
#  6      1.841051e+05
#  7      9.130316e+04
#  8      4.055073e+04
#  9      2.076087e+04  )

# %%
print('It took', round((time.time() - Start) / 60, 1), "minutes to run this script.")
# Out:
# It took 6.6 minutes to run this script.
