data = {
    "Scenarios": ["No_cons", "BAU", "AAC_90%", "AAC_80%", "AAC_70%", "AAC_60%", "AAC_50%", "AAC_40%", "AAC_30%", "AAC_20%", "AAC_10%"],
    "Carbon Stock": [3.0281551e+08, 2.9571112e+08, 2.9631432e+08, 2.9684921e+08, 2.9730985e+08, 2.9770685e+08, 2.9804215e+08, 2.9830457e+08, 2.9849336e+08, 2.9861205e+08, 2.986402162e+08],
    "Net Emissions": [-25461586, -29703226, -31862586, -33979373, -35983123, -38092738, -40163420, -42316628, -44282373, -46158178, -47882893],
    "Social Indicator": [19092, 7839, 7161, 6421, 5640, 4837, 4037, 3226, 2417, 1611, 830],
    "Economic Indicator": [651097, 267353, 244210, 218972, 192366, 164972, 137671, 110022, 82442, 54961, 28309],
    "Species Indicator": [0.8672, 0.8865, 0.8841, 0.8807, 0.8821, 0.8826, 0.8902, 0.9007, 0.9101, 0.9137, 0.9183],
    "Old Growth Indicator": [21909.01, 27443.4, 29600.82, 31646.53, 33795.67, 35917.61, 38082.24, 39850.99, 41620.09, 43769.33, 46221.27]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Normalize data for radar chart (scaling each indicator from 0 to 1)
for column in df.columns[1:]:
    min_val = df[column].min()
    max_val = df[column].max()
    df[column] = (df[column] - min_val) / (max_val - min_val)

# Prepare radar chart values
categories = list(df.columns[1:])
num_vars = len(categories)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Close the loop for the radar chart

# Initialize radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each scenario
for i, row in df.iterrows():
    values = row[1:].tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Scenarios'])
    ax.fill(angles, values, alpha=0.1)

# Customize chart
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)
plt.title("Radar Chart of Forestry Scenarios", fontsize=15, pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Data dictionary
data = {
    "Scenarios": ["No_cons", "BAU", "AAC_90%", "AAC_80%", "AAC_70%", "AAC_60%", "AAC_50%", "AAC_40%", "AAC_30%", "AAC_20%", "AAC_10%"],
    "Net Emissions": [-46089867, -33239922, -35415830, -37514129, -39494983, -41196986, -43010860, -44663712, -46281647, -47578947, -48617302],
    "Social Indicator": [2042, 7734, 6961, 6187, 5414, 4689, 3907, 3155, 2368, 1595, 797],
    "Economic Indicator": [69651, 263762, 237385, 211009, 184633, 159914, 133262, 107610, 80785, 54409, 27204],
    "Species Indicator": [0.9083, 0.7994, 0.8063, 0.8219, 0.8351, 0.8466, 0.8605, 0.8738, 0.8881, 0.9052, 0.9193],
    "Old Growth Indicator": [31890.3, 22638.01, 24952.22, 26658.73, 28003.44, 29480.62, 31573.01, 33969.4, 36780.47, 39921.46, 43205.58]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Normalize data for radar chart (scaling each indicator from 0 to 1)
for column in df.columns[1:]:
    min_val = df[column].min()
    max_val = df[column].max()
    df[column] = (df[column] - min_val) / (max_val - min_val)

# Prepare radar chart values
categories = list(df.columns[1:])
num_vars = len(categories)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Close the loop for the radar chart

# Initialize radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each scenario
for i, row in df.iterrows():
    values = row[1:].tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Scenarios'])
    ax.fill(angles, values, alpha=0.1)

# Customize chart
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)
plt.title("Radar Chart of Forestry Scenarios", fontsize=15, pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define the data
data = {
    'Scenarios': [
        'no_cons', '*_bau', '*_AAC_90%', '*_AAC_80%', '*_AAC_70%',
        '*_AAC_60%', '*_AAC_50%', '*_AAC_40%', '*_AAC_30%',
        '*_AAC_20%', '*_AAC_10%'
    ],
    'Net Emission': [
        -6.0559363e+06, -4.7511033e+06, -4.9088706e+06, -5.0539727e+06,
        -5.1880074e+06, -5.3110955e+06, -5.4232501e+06, -5.5219812e+06,
        -5.6050078e+06, -5.6653197e+06, -5.6956633e+06
    ],
    'Net Emissions': [
        -46089867, -33239922, -35415830, -37514129, -39494983,
        -41196986, -43010860, -44663712, -46281647, -47578947, -48617302
    ],
    'Social Indicator': [
        2042, 7734, 6961, 6187, 5414, 4689, 3907, 3155, 2368, 1595, 797
    ],
    'Economic Indicator': [
        69651, 263762, 237385, 211009, 184633, 159914, 133262, 107610,
        80785, 54409, 27204
    ],
    'Species Indicator (Time=10)': [
        0.9083, 0.7994, 0.8063, 0.8219, 0.8351, 0.8466, 0.8605,
        0.8738, 0.8881, 0.9052, 0.9193
    ],
    'Old Growth Indicator (ha, Time=10)': [
        31890.3, 22638.01, 24952.22, 26658.73, 28003.44, 29480.62,
        31573.01, 33969.4, 36780.47, 39921.46, 43205.58
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the position of the bars on the x-axis
ind = np.arange(len(df['Scenarios']))  # the x locations for the groups
width = 0.15  # the width of the bars

# Create subplots for better readability due to multiple indicators
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
fig.suptitle('Comparison of Indicators Across Scenarios for Forest Management', fontsize=16)

# Define the indicators to plot
indicators = [
    'Net Emission',
    'Net Emissions',
    'Social Indicator',
    'Economic Indicator',
    'Species Indicator (Time=10)',
    'Old Growth Indicator (ha, Time=10)'
]

# Plot each indicator
for ax, indicator in zip(axes.flatten(), indicators):
    ax.bar(ind, df[indicator], width, label=indicator, color='skyblue')
    ax.set_title(indicator)
    ax.set_xlabel('Scenarios')
    ax.set_ylabel(indicator)
    ax.set_xticks(ind)
    ax.set_xticklabels(df['Scenarios'], rotation=45, ha='right')
    ax.grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Updated Data dictionary with Harvest Volume
data = {
    "Scenarios": ["No_cons", "BAU", "AAC_90%", "AAC_80%", "AAC_70%", "AAC_60%", "AAC_50%", "AAC_40%", "AAC_30%", "AAC_20%", "AAC_10%"],
    "Harvest Volume": [3.0063889e+07, 1.1211387e+07, 1.009025875e+07, 8.96912e+06, 7.8479813e+06, 6.7268427e+06, 5.605704e+06, 4.4845652e+06, 3.3634266e+06, 2.2422878e+06, 1.1211492e+06],
    "Net Emissions": [-47748762, -46083355, -50234031, -52652856, -56559028, -61565532, -64192028, -68328829, -71715541, -76112747, -78934797],
    "Social Indicator": [31783, 11852, 10667, 9482, 8296, 7111, 5926, 4741, 3555, 2370, 1185],
    "Economic Indicator": [1083897, 404205, 363785, 323364, 282944, 242523, 202103, 161682, 121262, 80841, 40420],
    "Species Indicator": [0.6880, 0.7804, 0.7774, 0.7825, 0.7852, 0.7786, 0.7707, 0.7725, 0.7810, 0.7804, 0.7985],
    "Old Growth Indicator": [47244, 100401, 104475, 106839.5, 110990.7, 114144.5, 115217.4, 119934.8, 124733.5, 128285.5, 139178.5]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Normalize data for radar chart (scaling each indicator from 0 to 1)
for column in df.columns[1:]:
    min_val = df[column].min()
    max_val = df[column].max()
    df[column] = (df[column] - min_val) / (max_val - min_val)

# Prepare radar chart values
categories = list(df.columns[1:])
num_vars = len(categories)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Close the loop for the radar chart

# Initialize radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each scenario
for i, row in df.iterrows():
    values = row[1:].tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Scenarios'])
    ax.fill(angles, values, alpha=0.1)

# Customize chart
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)
plt.title("Radar Chart of Forestry Scenarios", fontsize=15, pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Updated Data dictionary with Harvest Area
data = {
    "Scenarios": ["No_cons", "BAU", "AAC_90%", "AAC_80%", "AAC_70%", "AAC_60%", "AAC_50%", "AAC_30%", "AAC_20%", "AAC_10%"],
    "Harvest Area": [np.nan, 5.9129592e+04, 5.2317333e+04, 4.5728340e+04, 3.9326668e+04, 3.3093378e+04, 2.7023194e+04, 1.5497567e+04, 1.0023503e+04, 4.7586155e+03],
    "Net Emissions": [-81552275, -60129917, -62486615, -64832416, -67151265, -69383983, -71593454, -75962420, -77708010, -79628597],
    "Social Indicator": [np.nan, 10831, 9748, 8665, 7582, 6499, 5449, 3262, 2172, 1089],
    "Economic Indicator": [np.nan, 369393, 332454, 295514, 258575, 221636, 185826, 111260, 74096, 37169],
    "Species Indicator": [0.8120, 0.8507, 0.8461, 0.8435, 0.8370, 0.8341, 0.8279, 0.8179, 0.8178, 0.8159],
    "Old Growth Indicator": [150237.5, 111298.1, 116224.3, 119077.2, 122514.1, 126483.9, 129808.9, 138646.6, 142010.7, 146688.7]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Fill missing values in numeric columns with the mean of each column
df.update(df.select_dtypes(include=[np.number]).fillna(df.mean(numeric_only=True)))

# Normalize data for radar chart (scaling each indicator from 0 to 1)
for column in df.columns[1:]:
    min_val = df[column].min()
    max_val = df[column].max()
    df[column] = (df[column] - min_val) / (max_val - min_val)

# Prepare radar chart values
categories = list(df.columns[1:])
num_vars = len(categories)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Close the loop for the radar chart

# Initialize radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each scenario
for i, row in df.iterrows():
    values = row[1:].tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Scenarios'])
    ax.fill(angles, values, alpha=0.1)

# Customize chart
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)
plt.title("Radar Chart of Forestry Scenarios", fontsize=15, pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Updated Data dictionary with Harvest Area
data = {
    "Scenarios": ["No_cons", "BAU", "AAC_90%", "AAC_80%", "AAC_70%", "AAC_60%", "AAC_50%", "AAC_30%", "AAC_20%", "AAC_10%"],
    "Harvest Area": [np.nan, 5.9129592e+04, 5.2317333e+04, 4.5728340e+04, 3.9326668e+04, 3.3093378e+04, 2.7023194e+04, 1.5497567e+04, 1.0023503e+04, 4.7586155e+03],
    "Net Emissions": [-81552275, -60129917, -62486615, -64832416, -67151265, -69383983, -71593454, -75962420, -77708010, -79628597],
    "Social Indicator": [np.nan, 10831, 9748, 8665, 7582, 6499, 5449, 3262, 2172, 1089],
    "Economic Indicator": [np.nan, 369393, 332454, 295514, 258575, 221636, 185826, 111260, 74096, 37169],
    "Species Indicator": [0.8120, 0.8507, 0.8461, 0.8435, 0.8370, 0.8341, 0.8279, 0.8179, 0.8178, 0.8159],
    "Old Growth Indicator": [150237.5, 111298.1, 116224.3, 119077.2, 122514.1, 126483.9, 129808.9, 138646.6, 142010.7, 146688.7]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Fill missing values in numeric columns with the mean of each column
df.update(df.select_dtypes(include=[np.number]).fillna(df.mean(numeric_only=True)))

# Normalize data for radar chart (scaling each indicator from 0 to 1)
for column in df.columns[1:]:
    min_val = df[column].min()
    max_val = df[column].max()
    df[column] = (df[column] - min_val) / (max_val - min_val)

# Prepare radar chart values
categories = list(df.columns[1:])
num_vars = len(categories)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Close the loop for the radar chart

# Initialize radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each scenario
for i, row in df.iterrows():
    values = row[1:].tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Scenarios'])
    ax.fill(angles, values, alpha=0.1)

# Customize chart
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)
plt.title("Radar Chart of Forestry Scenarios", fontsize=15, pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Define the data dictionary based on your provided data
data = {
    "Scenarios": [
        "no_cons", "*_bau", "*_AAC_90%", "*_AAC_80%", "*_AAC_70%", "*_AAC_60%",
        "*_AAC_50%", "*_AAC_40%", "*_AAC_30%", "*_AAC_20%", "*_AAC_10%"
    ],
    "Net Emission": [
        -1.1394919e+07, -9.1111672e+06, -9.2676391e+06, -9.4151818e+06,
        -9.5550748e+06, -9.6871275e+06, -9.8139205e+06, -9.9309202e+06,
        -1.0037550e+07, -1.0134362e+07, -1.0217076e+07
    ],
    "Net Emissions": [
        -67795804, -61796778, -64047320, -66281064, -68400960, -70675677,
        -72760412, -74604781, -76729441, -78730608, -80475093
    ],
    "Social Indicator (No. of jobs)": [
        7941, 10945, 9850, 8756, 7661, 6567, 5472, 4423, 3317, 2211, 1117
    ],
    "Economic Indicator ($)": [
        270811, 373261, 335935, 298609, 261283, 223956, 186630, 150851, 113138, 75425, 38099
    ],
    "Species Indicator (Time=10)": [
        0.7657, 0.6474, 0.6559, 0.6728, 0.6763, 0.7074, 0.7208, 0.7305, 0.7585, 0.7787, 0.7992
    ],
    "Old Growth Indicator (ha, Time =10)": [
        76536.91, 81760.31, 85177.54, 89999.94, 95284.54, 104073.4, 111517.6,
        118217, 129454.6, 137110.4, 144919
    ]
}

# Load the data into a DataFrame
df = pd.DataFrame(data)

# Fill any missing values in numeric columns with the mean of each column (if needed)
df.update(df.select_dtypes(include=[np.number]).fillna(df.mean(numeric_only=True)))

# Normalize data for radar chart (scaling each indicator from 0 to 1)
for column in df.columns[1:]:
    min_val = df[column].min()
    max_val = df[column].max()
    df[column] = (df[column] - min_val) / (max_val - min_val)

# Prepare radar chart values
categories = list(df.columns[1:])
num_vars = len(categories)
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]  # Complete the loop for the radar chart

# Initialize radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each scenario on the radar chart
for i, row in df.iterrows():
    values = row[1:].tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=row['Scenarios'])
    ax.fill(angles, values, alpha=0.1)

# Customize the chart
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=12)
plt.title("Radar Chart of Forestry Scenarios", fontsize=15, pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

# Display the plot
plt.show()
