# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for equitysilver_max_hv_no_cons_cbm_output_2.csv: 2860992.618537843
# Total Net emission for equitysilver_max_hv_evenflow_cons_cbm_output_2.csv: 44209174.60710718
# Total Net emission for equitysilver_max_hv_bau_eqtslvr_cbm_output_2.csv: -10187414.263133507
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_90%_cbm_output_2.csv: -20190655.621586952
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_80%_cbm_output_2.csv: -37717399.64487405
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_70%_cbm_output_2.csv: -53571451.0172023
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_60%_cbm_output_2.csv: -69020879.6592295
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_50%_cbm_output_2.csv: -83747319.36786279
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_40%_cbm_output_2.csv: -96901488.83035089
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_30%_cbm_output_2.csv: -116527826.65354964
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_20%_cbm_output_2.csv: -127261518.62398413
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_10%_cbm_output_2.csv: -141630206.1379986
# Total Net emission for equitysilver_min_ha_no_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_ha_evenflow_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_ha_bau_eqtslvr_cbm_output_2.csv: -27541849.537715495
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_90%_cbm_output_2.csv: -42297895.29734119
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_80%_cbm_output_2.csv: -55475110.39524106
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_70%_cbm_output_2.csv: -69237782.71690026
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_60%_cbm_output_2.csv: -83282990.39558902
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_50%_cbm_output_2.csv: -96462861.76470698
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_40%_cbm_output_2.csv: -109037924.40942132
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_30%_cbm_output_2.csv: -121829519.11944251
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_20%_cbm_output_2.csv: -133928525.14885981
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_10%_cbm_output_2.csv: -144780424.59899876
# Total Net emission for equitysilver_max_st_no_cons_cbm_output_2.csv: 4940923.654842515
# Total Net emission for equitysilver_max_st_evenflow_cons_cbm_output_2.csv: -94779338.30454934
# Total Net emission for equitysilver_max_st_bau_eqtslvr_cbm_output_2.csv: -11210602.40032918
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_90%_cbm_output_2.csv: -25123737.914231516
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_80%_cbm_output_2.csv: -38302614.73162477
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_70%_cbm_output_2.csv: -51118148.32176064
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_60%_cbm_output_2.csv: -67214671.6242659
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_50%_cbm_output_2.csv: -83016350.8946636
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_40%_cbm_output_2.csv: -96096345.03873113
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_30%_cbm_output_2.csv: -108992495.12353607
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_20%_cbm_output_2.csv: -123029336.64131175
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_10%_cbm_output_2.csv: -137894918.86059934
# Total Net emission for equitysilver_min_em_no_cons_cbm_output_2.csv: -80429040.24587803
# Total Net emission for equitysilver_min_em_evenflow_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_em_bau_eqtslvr_cbm_output_2.csv: -32283327.06203387
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_90%_cbm_output_2.csv: -48004007.05553797
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_80%_cbm_output_2.csv: -63158300.980297364
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_70%_cbm_output_2.csv: -77733865.80003195
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_60%_cbm_output_2.csv: -92262442.5575993
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_50%_cbm_output_2.csv: -105336074.3032615
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_40%_cbm_output_2.csv: -117412129.29723579
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_30%_cbm_output_2.csv: -129450679.87125923
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_20%_cbm_output_2.csv: -140106761.77958354
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_10%_cbm_output_2.csv: -148587923.0140485

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        # Initialize a list to store results for plotting
        scenario_names = []
        net_emissions = []

        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()

                # Append the scenario and net emission sum to the lists
                scenario_names.append(f'{scenario_name} ({file_path})')
                net_emissions.append(net_emission_sum)

        # Create a bar plot for this combination of case and mode
        plt.figure(figsize=(10, 6))
        plt.barh(scenario_names, net_emissions, color='skyblue')
        plt.xlabel('Total Net Emission')
        plt.title(f'Net Emission for {case} ({mode})')
        plt.tight_layout()
        plt.show()
