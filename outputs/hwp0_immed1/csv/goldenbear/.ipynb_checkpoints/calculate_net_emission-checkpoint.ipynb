# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for goldenbear_max_hv_no_cons_cbm_output_2.csv: -25056046.394944146
# Total Net emission for goldenbear_max_hv_evenflow_cons_cbm_output_2.csv: -2241183.902175618
# Total Net emission for goldenbear_max_hv_bau_gldbr_cbm_output_2.csv: -16033982.846142964
# Total Net emission for goldenbear_max_hv_gldbr_AAC_90%_cbm_output_2.csv: -18752078.60817651
# Total Net emission for goldenbear_max_hv_gldbr_AAC_80%_cbm_output_2.csv: -22600496.269727673
# Total Net emission for goldenbear_max_hv_gldbr_AAC_70%_cbm_output_2.csv: -26269792.813777775
# Total Net emission for goldenbear_max_hv_gldbr_AAC_60%_cbm_output_2.csv: -29451625.917271942
# Total Net emission for goldenbear_max_hv_gldbr_AAC_50%_cbm_output_2.csv: -32648597.0961686
# Total Net emission for goldenbear_max_hv_gldbr_AAC_40%_cbm_output_2.csv: -36285742.78389081
# Total Net emission for goldenbear_max_hv_gldbr_AAC_30%_cbm_output_2.csv: -39484504.79277252
# Total Net emission for goldenbear_max_hv_gldbr_AAC_20%_cbm_output_2.csv: -42876921.56524795
# Total Net emission for goldenbear_max_hv_gldbr_AAC_10%_cbm_output_2.csv: -46028371.60668996
# Total Net emission for goldenbear_min_ha_no_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_ha_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_ha_bau_gldbr_cbm_output_2.csv: -28515638.598843332
# Total Net emission for goldenbear_min_ha_gldbr_AAC_90%_cbm_output_2.csv: -31034000.861215055
# Total Net emission for goldenbear_min_ha_gldbr_AAC_80%_cbm_output_2.csv: -33542297.554664712
# Total Net emission for goldenbear_min_ha_gldbr_AAC_70%_cbm_output_2.csv: -35883892.12471517
# Total Net emission for goldenbear_min_ha_gldbr_AAC_60%_cbm_output_2.csv: -38069878.04389411
# Total Net emission for goldenbear_min_ha_gldbr_AAC_50%_cbm_output_2.csv: -40330195.689392
# Total Net emission for goldenbear_min_ha_gldbr_AAC_40%_cbm_output_2.csv: -42268680.291813836
# Total Net emission for goldenbear_min_ha_gldbr_AAC_30%_cbm_output_2.csv: -44139823.19026495
# Total Net emission for goldenbear_min_ha_gldbr_AAC_20%_cbm_output_2.csv: -46042530.61875566
# Total Net emission for goldenbear_min_ha_gldbr_AAC_10%_cbm_output_2.csv: -47805046.84302281
# Total Net emission for goldenbear_max_st_no_cons_cbm_output_2.csv: -38339056.16004451
# Total Net emission for goldenbear_max_st_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_max_st_bau_gldbr_cbm_output_2.csv: -27691925.353361275
# Total Net emission for goldenbear_max_st_gldbr_AAC_90%_cbm_output_2.csv: -30104959.36436405
# Total Net emission for goldenbear_max_st_gldbr_AAC_80%_cbm_output_2.csv: -32488813.048389006
# Total Net emission for goldenbear_max_st_gldbr_AAC_70%_cbm_output_2.csv: -34768113.35663146
# Total Net emission for goldenbear_max_st_gldbr_AAC_60%_cbm_output_2.csv: -37087910.77906362
# Total Net emission for goldenbear_max_st_gldbr_AAC_50%_cbm_output_2.csv: -39329996.040974826
# Total Net emission for goldenbear_max_st_gldbr_AAC_40%_cbm_output_2.csv: -41640615.98557062
# Total Net emission for goldenbear_max_st_gldbr_AAC_30%_cbm_output_2.csv: -43767880.03389894
# Total Net emission for goldenbear_max_st_gldbr_AAC_20%_cbm_output_2.csv: -45807835.566094816
# Total Net emission for goldenbear_max_st_gldbr_AAC_10%_cbm_output_2.csv: -47753225.51330039
# Total Net emission for goldenbear_min_em_no_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_em_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_em_bau_gldbr_cbm_output_2.csv: -31101737.200817674
# Total Net emission for goldenbear_min_em_gldbr_AAC_90%_cbm_output_2.csv: -33517262.861361418
# Total Net emission for goldenbear_min_em_gldbr_AAC_80%_cbm_output_2.csv: -35826513.76201317
# Total Net emission for goldenbear_min_em_gldbr_AAC_70%_cbm_output_2.csv: -38018319.192219995
# Total Net emission for goldenbear_min_em_gldbr_AAC_60%_cbm_output_2.csv: -40079144.82277937
# Total Net emission for goldenbear_min_em_gldbr_AAC_50%_cbm_output_2.csv: -42087880.740244456
# Total Net emission for goldenbear_min_em_gldbr_AAC_40%_cbm_output_2.csv: -43982483.97217502
# Total Net emission for goldenbear_min_em_gldbr_AAC_30%_cbm_output_2.csv: -45740657.14017139
# Total Net emission for goldenbear_min_em_gldbr_AAC_20%_cbm_output_2.csv: -47230475.53216593
# Total Net emission for goldenbear_min_em_gldbr_AAC_10%_cbm_output_2.csv: -48427198.91328283
