# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for redchris_max_hv_no_cons_cbm_output_2.csv: -37187559.27914668
# Total Net emission for redchris_max_hv_evenflow_cons_cbm_output_2.csv: -13163586.284561338
# Total Net emission for redchris_max_hv_bau_redchrs_cbm_output_2.csv: -42788882.10880634
# Total Net emission for redchris_max_hv_redchrs_AAC_90%_cbm_output_2.csv: -47269002.30610237
# Total Net emission for redchris_max_hv_redchrs_AAC_80%_cbm_output_2.csv: -50017274.98888505
# Total Net emission for redchris_max_hv_redchrs_AAC_70%_cbm_output_2.csv: -54252893.97928124
# Total Net emission for redchris_max_hv_redchrs_AAC_60%_cbm_output_2.csv: -59588845.169359766
# Total Net emission for redchris_max_hv_redchrs_AAC_50%_cbm_output_2.csv: -62544788.6398357
# Total Net emission for redchris_max_hv_redchrs_AAC_40%_cbm_output_2.csv: -67011037.20841047
# Total Net emission for redchris_max_hv_redchrs_AAC_30%_cbm_output_2.csv: -70727196.92963403
# Total Net emission for redchris_max_hv_redchrs_AAC_20%_cbm_output_2.csv: -75453849.66978718
# Total Net emission for redchris_max_hv_redchrs_AAC_10%_cbm_output_2.csv: -78605347.33256027
# Total Net emission for redchris_min_ha_no_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for redchris_min_ha_evenflow_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for redchris_min_ha_bau_redchrs_cbm_output_2.csv: -57135432.989622556
# Total Net emission for redchris_min_ha_redchrs_AAC_90%_cbm_output_2.csv: -59791578.694637224
# Total Net emission for redchris_min_ha_redchrs_AAC_80%_cbm_output_2.csv: -62436828.06153221
# Total Net emission for redchris_min_ha_redchrs_AAC_70%_cbm_output_2.csv: -65055126.49750722
# Total Net emission for redchris_min_ha_redchrs_AAC_60%_cbm_output_2.csv: -67587292.88458744
# Total Net emission for redchris_min_ha_redchrs_AAC_50%_cbm_output_2.csv: -70085324.64289396
# Total Net emission for redchris_min_ha_redchrs_AAC_40%_cbm_output_2.csv: -72576429.7076922
# Total Net emission for redchris_min_ha_redchrs_AAC_30%_cbm_output_2.csv: -75059822.97131152
# Total Net emission for redchris_min_ha_redchrs_AAC_20%_cbm_output_2.csv: -77106951.57221247
# Total Net emission for redchris_min_ha_redchrs_AAC_10%_cbm_output_2.csv: -79327068.78641465
# Total Net emission for redchris_max_st_no_cons_cbm_output_2.csv: -32837523.2665834
# Total Net emission for redchris_max_st_evenflow_cons_cbm_output_2.csv: -81139882.89206114
# Total Net emission for redchris_max_st_bau_redchrs_cbm_output_2.csv: -54944905.86415657
# Total Net emission for redchris_max_st_redchrs_AAC_90%_cbm_output_2.csv: -57605343.1324818
# Total Net emission for redchris_max_st_redchrs_AAC_80%_cbm_output_2.csv: -60369970.68636937
# Total Net emission for redchris_max_st_redchrs_AAC_70%_cbm_output_2.csv: -63021266.68799478
# Total Net emission for redchris_max_st_redchrs_AAC_60%_cbm_output_2.csv: -65674859.86191671
# Total Net emission for redchris_max_st_redchrs_AAC_50%_cbm_output_2.csv: -68359230.77466053
# Total Net emission for redchris_max_st_redchrs_AAC_40%_cbm_output_2.csv: -70848050.7655216
# Total Net emission for redchris_max_st_redchrs_AAC_30%_cbm_output_2.csv: -73624408.99935603
# Total Net emission for redchris_max_st_redchrs_AAC_20%_cbm_output_2.csv: -76281988.06444466
# Total Net emission for redchris_max_st_redchrs_AAC_10%_cbm_output_2.csv: -79055210.45849067
# Total Net emission for redchris_min_em_no_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for redchris_min_em_evenflow_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for redchris_min_em_bau_redchrs_cbm_output_2.csv: -59101238.864536084
# Total Net emission for redchris_min_em_redchrs_AAC_90%_cbm_output_2.csv: -61603640.92377034
# Total Net emission for redchris_min_em_redchrs_AAC_80%_cbm_output_2.csv: -64093875.148680724
# Total Net emission for redchris_min_em_redchrs_AAC_70%_cbm_output_2.csv: -66502133.859472185
# Total Net emission for redchris_min_em_redchrs_AAC_60%_cbm_output_2.csv: -69052718.87612773
# Total Net emission for redchris_min_em_redchrs_AAC_50%_cbm_output_2.csv: -71393371.63367887
# Total Net emission for redchris_min_em_redchrs_AAC_40%_cbm_output_2.csv: -73580047.08074814
# Total Net emission for redchris_min_em_redchrs_AAC_30%_cbm_output_2.csv: -75985133.97255118
# Total Net emission for redchris_min_em_redchrs_AAC_20%_cbm_output_2.csv: -78213302.79058756
# Total Net emission for redchris_min_em_redchrs_AAC_10%_cbm_output_2.csv: -80216670.36676525
