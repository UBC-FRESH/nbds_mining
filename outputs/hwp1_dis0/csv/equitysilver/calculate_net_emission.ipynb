# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for equitysilver_max_hv_no_cons_cbm_output_2.csv: 49313302.09146845
# Total Net emission for equitysilver_max_hv_evenflow_cons_cbm_output_2.csv: 80774884.94151174
# Total Net emission for equitysilver_max_hv_bau_eqtslvr_cbm_output_2.csv: -10187414.263133507
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_90%_cbm_output_2.csv: 5035432.125559012
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_80%_cbm_output_2.csv: -15294210.1951066
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_70%_cbm_output_2.csv: -33951159.86481341
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_60%_cbm_output_2.csv: -52203486.8042191
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_50%_cbm_output_2.csv: -69732824.81023093
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_40%_cbm_output_2.csv: -88495877.72003078
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_30%_cbm_output_2.csv: -108119128.69067484
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_20%_cbm_output_2.csv: -121655718.95848782
# Total Net emission for equitysilver_max_hv_eqtslvr_AAC_10%_cbm_output_2.csv: -138827304.76988083
# Total Net emission for equitysilver_min_ha_no_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_ha_evenflow_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_ha_bau_eqtslvr_cbm_output_2.csv: -27541849.537715495
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_90%_cbm_output_2.csv: -19368848.774677735
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_80%_cbm_output_2.csv: -35093735.708429106
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_70%_cbm_output_2.csv: -51404079.8659398
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_60%_cbm_output_2.csv: -67996959.38048007
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_50%_cbm_output_2.csv: -83724502.58544952
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_40%_cbm_output_2.csv: -98847237.06601536
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_30%_cbm_output_2.csv: -114186503.61188804
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_20%_cbm_output_2.csv: -128833181.47715679
# Total Net emission for equitysilver_min_ha_eqtslvr_AAC_10%_cbm_output_2.csv: -142232752.76314726
# Total Net emission for equitysilver_max_st_no_cons_cbm_output_2.csv: 39990571.851882815
# Total Net emission for equitysilver_max_st_evenflow_cons_cbm_output_2.csv: -146782375.38750383
# Total Net emission for equitysilver_max_st_bau_eqtslvr_cbm_output_2.csv: -11210602.40032918
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_90%_cbm_output_2.csv: -1567257.0690082216
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_80%_cbm_output_2.csv: -17579505.154083032
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_70%_cbm_output_2.csv: -33954333.69472089
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_60%_cbm_output_2.csv: -51454376.189566456
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_50%_cbm_output_2.csv: -69763899.08016877
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_40%_cbm_output_2.csv: -85494322.7725234
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_30%_cbm_output_2.csv: -102043691.03718129
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_20%_cbm_output_2.csv: -118504650.19919637
# Total Net emission for equitysilver_max_st_eqtslvr_AAC_10%_cbm_output_2.csv: -136158018.91667765
# Total Net emission for equitysilver_min_em_no_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_em_evenflow_cons_cbm_output_2.csv: -155624647.13889873
# Total Net emission for equitysilver_min_em_bau_eqtslvr_cbm_output_2.csv: -32283327.06203387
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_90%_cbm_output_2.csv: -27985365.578214686
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_80%_cbm_output_2.csv: -45050146.62142195
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_70%_cbm_output_2.csv: -61926901.51736462
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_60%_cbm_output_2.csv: -78499564.34192584
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_50%_cbm_output_2.csv: -93758213.99416357
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_40%_cbm_output_2.csv: -108738336.34825249
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_30%_cbm_output_2.csv: -122783956.96833138
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_20%_cbm_output_2.csv: -135519783.46183908
# Total Net emission for equitysilver_min_em_eqtslvr_AAC_10%_cbm_output_2.csv: -146146414.00805822
