# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for goldenbear_max_hv_no_cons_cbm_output_2.csv: -21580295.892334685
# Total Net emission for goldenbear_max_hv_evenflow_cons_cbm_output_2.csv: -2088635.200812868
# Total Net emission for goldenbear_max_hv_bau_gldbr_cbm_output_2.csv: -15974957.43344308
# Total Net emission for goldenbear_max_hv_gldbr_AAC_90%_cbm_output_2.csv: -18698955.65969659
# Total Net emission for goldenbear_max_hv_gldbr_AAC_80%_cbm_output_2.csv: -22553275.862517737
# Total Net emission for goldenbear_max_hv_gldbr_AAC_70%_cbm_output_2.csv: -26228474.947837826
# Total Net emission for goldenbear_max_hv_gldbr_AAC_60%_cbm_output_2.csv: -29416210.592601974
# Total Net emission for goldenbear_max_hv_gldbr_AAC_50%_cbm_output_2.csv: -32619084.31276862
# Total Net emission for goldenbear_max_hv_gldbr_AAC_40%_cbm_output_2.csv: -36262132.54176083
# Total Net emission for goldenbear_max_hv_gldbr_AAC_30%_cbm_output_2.csv: -39466797.09191253
# Total Net emission for goldenbear_max_hv_gldbr_AAC_20%_cbm_output_2.csv: -42865116.40565794
# Total Net emission for goldenbear_max_hv_gldbr_AAC_10%_cbm_output_2.csv: -46022468.988369934
# Total Net emission for goldenbear_min_ha_no_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_ha_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_ha_bau_gldbr_cbm_output_2.csv: -28482276.910131093
# Total Net emission for goldenbear_min_ha_gldbr_AAC_90%_cbm_output_2.csv: -31006848.258834288
# Total Net emission for goldenbear_min_ha_gldbr_AAC_80%_cbm_output_2.csv: -33515104.977674097
# Total Net emission for goldenbear_min_ha_gldbr_AAC_70%_cbm_output_2.csv: -35861748.020823054
# Total Net emission for goldenbear_min_ha_gldbr_AAC_60%_cbm_output_2.csv: -38041151.1443993
# Total Net emission for goldenbear_min_ha_gldbr_AAC_50%_cbm_output_2.csv: -40315863.11593471
# Total Net emission for goldenbear_min_ha_gldbr_AAC_40%_cbm_output_2.csv: -42257104.42974884
# Total Net emission for goldenbear_min_ha_gldbr_AAC_30%_cbm_output_2.csv: -44131223.64619057
# Total Net emission for goldenbear_min_ha_gldbr_AAC_20%_cbm_output_2.csv: -46036797.589372754
# Total Net emission for goldenbear_min_ha_gldbr_AAC_10%_cbm_output_2.csv: -47801055.97228965
# Total Net emission for goldenbear_max_st_no_cons_cbm_output_2.csv: -20071727.534866884
# Total Net emission for goldenbear_max_st_evenflow_cons_cbm_output_2.csv: -49064601.02626981
# Total Net emission for goldenbear_max_st_bau_gldbr_cbm_output_2.csv: -27663260.2064467
# Total Net emission for goldenbear_max_st_gldbr_AAC_90%_cbm_output_2.csv: -29939169.86056692
# Total Net emission for goldenbear_max_st_gldbr_AAC_80%_cbm_output_2.csv: -32250749.00047021
# Total Net emission for goldenbear_max_st_gldbr_AAC_70%_cbm_output_2.csv: -34548415.31951167
# Total Net emission for goldenbear_max_st_gldbr_AAC_60%_cbm_output_2.csv: -36850565.92581389
# Total Net emission for goldenbear_max_st_gldbr_AAC_50%_cbm_output_2.csv: -39140120.82974743
# Total Net emission for goldenbear_max_st_gldbr_AAC_40%_cbm_output_2.csv: -41419682.66715092
# Total Net emission for goldenbear_max_st_gldbr_AAC_30%_cbm_output_2.csv: -43607066.13092548
# Total Net emission for goldenbear_max_st_gldbr_AAC_20%_cbm_output_2.csv: -45709469.64463676
# Total Net emission for goldenbear_max_st_gldbr_AAC_10%_cbm_output_2.csv: -47701234.58401206
# Total Net emission for goldenbear_min_em_no_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_em_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_em_bau_gldbr_cbm_output_2.csv: -31101737.200817674
# Total Net emission for goldenbear_min_em_gldbr_AAC_90%_cbm_output_2.csv: -33491464.229138296
# Total Net emission for goldenbear_min_em_gldbr_AAC_80%_cbm_output_2.csv: -35803581.6444815
# Total Net emission for goldenbear_min_em_gldbr_AAC_70%_cbm_output_2.csv: -37998253.58937979
# Total Net emission for goldenbear_min_em_gldbr_AAC_60%_cbm_output_2.csv: -40061945.73463064
# Total Net emission for goldenbear_min_em_gldbr_AAC_50%_cbm_output_2.csv: -42073548.166787155
# Total Net emission for goldenbear_min_em_gldbr_AAC_40%_cbm_output_2.csv: -43971017.91340919
# Total Net emission for goldenbear_min_em_gldbr_AAC_30%_cbm_output_2.csv: -45732057.59609702
# Total Net emission for goldenbear_min_em_gldbr_AAC_20%_cbm_output_2.csv: -47224742.50278302
# Total Net emission for goldenbear_min_em_gldbr_AAC_10%_cbm_output_2.csv: -48424332.39859137
